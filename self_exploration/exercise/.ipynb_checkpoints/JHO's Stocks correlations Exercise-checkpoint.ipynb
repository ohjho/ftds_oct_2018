# %% [markdown]
# ## Stock Index Constituents Returns Correlations Heatmap
# ### Using Pandas, Pandas Datareader, and Seaborn

# %% [markdown]
# #### First Thing First, load up pandas, seaborn, and the data readers

# %%
import pandas as pd
from pandas_datareader import data as web
from datetime import datetime as dt

import os # for file writing *maybe*

# for ploting we need:
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Define our index constituents and get the data

# %%
lsymbols= [
    'SPY',
    'GLD',
    'EEM',
    'QQQ',
    'IWM',
    'VXX',
    'USO',
    'GDX',
    'MJ'
]
sdate = dt(2017,1,1)
yhoo_df = web.DataReader(lsymbols, 'yahoo',sdate, dt.now())

# %% [markdown]
# #### Check out the resulting Data frame

# %%
yhoo_df.head()
# Out:
# Attributes       High                                                \
# Symbols           EEM        GDX         GLD         IWM         MJ
# Date
# 2017-01-03  35.650002  21.770000  111.000000  136.830002  24.681999
# 2017-01-04  35.770000  22.010000  111.220001  137.960007  25.010000
# 2017-01-05  36.150002  23.350000  112.940002  137.759995  25.100000
# 2017-01-06  36.000000  23.090000  112.379997  136.710007  25.010000
# 2017-01-09  36.000000  22.940001  113.040001  135.720001  24.980000
#
# Attributes                                                  Low    ...      \
# Symbols            QQQ         SPY    USO        VXX        EEM    ...
# Date                                                               ...
# 2017-01-03  119.989998  225.830002  12.00  98.639999  35.299999    ...
# 2017-01-04  120.410004  226.750000  11.63  93.720001  35.610001    ...
# 2017-01-05  120.949997  226.580002  11.79  92.320000  35.939999    ...
# 2017-01-06  122.250000  227.750000  11.81  89.400002  35.840000    ...
# 2017-01-09  122.550003  227.070007  11.53  89.639999  35.869999    ...
#
# Attributes     Volume  Adj Close                                     \
# Symbols           VXX        EEM        GDX         GLD         IWM
# Date
# 2017-01-03  9778700.0  34.514641  21.585840  110.470001  132.576813
# 2017-01-04  8906900.0  34.777668  21.744560  110.860001  134.787720
# 2017-01-05  7176100.0  35.157589  23.014317  112.580002  133.232254
# 2017-01-06  9998600.0  35.011463  22.210798  111.750000  132.743088
# 2017-01-09  7320700.0  34.982243  22.280237  112.669998  131.872452
#
# Attributes
# Symbols            MJ         QQQ         SPY    USO        VXX
# Date
# 2017-01-03  24.495026  117.803764  218.092178  11.44  94.800003
# 2017-01-04  24.646267  118.444321  219.389679  11.58  89.919998
# 2017-01-05  24.805468  119.114441  219.215363  11.70  89.599998
# 2017-01-06  24.855217  120.159035  219.999664  11.68  88.519997
# 2017-01-09  24.855217  120.553238  219.273499  11.31  88.160004
#
# [5 rows x 54 columns]

# %%
yhoo_df.dtypes
# Out:
# Attributes  Symbols
# High        EEM        float64
#             GDX        float64
#             GLD        float64
#             IWM        float64
#             MJ         float64
#             QQQ        float64
#             SPY        float64
#             USO        float64
#             VXX        float64
# Low         EEM        float64
#             GDX        float64
#             GLD        float64
#             IWM        float64
#             MJ         float64
#             QQQ        float64
#             SPY        float64
#             USO        float64
#             VXX        float64
# Open        EEM        float64
#             GDX        float64
#             GLD        float64
#             IWM        float64
#             MJ         float64
#             QQQ        float64
#             SPY        float64
#             USO        float64
#             VXX        float64
# Close       EEM        float64
#             GDX        float64
#             GLD        float64
#             IWM        float64
#             MJ         float64
#             QQQ        float64
#             SPY        float64
#             USO        float64
#             VXX        float64
# Volume      EEM        float64
#             GDX        float64
#             GLD        float64
#             IWM        float64
#             MJ         float64
#             QQQ        float64
#             SPY        float64
#             USO        float64
#             VXX        float64
# Adj Close   EEM        float64
#             GDX        float64
#             GLD        float64
#             IWM        float64
#             MJ         float64
#             QQQ        float64
#             SPY        float64
#             USO        float64
#             VXX        float64
# dtype: object

# %%
yhoo_df.index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2018-10-05', '2018-10-08', '2018-10-09', '2018-10-10',
#                '2018-10-11', '2018-10-12', '2018-10-15', '2018-10-16',
#                '2018-10-17', '2018-10-18'],
#               dtype='datetime64[ns]', name='Date', length=453, freq=None)

# %% [markdown]
# #### Let's reshape the data into something easier to work with

# %%
df = yhoo_df.stack()
df.head(10)
# Out:
# Attributes                High         Low        Open       Close  \
# Date       Symbols
# 2017-01-03 EEM       35.650002   35.299999   35.389999   35.430000
#            GDX       21.770000   20.980000   21.070000   21.760000
#            GLD      111.000000  109.370003  109.620003  110.470001
#            IWM      136.830002  134.500000  136.490005  135.520004
#            MJ        24.681999   24.510000   24.510000   24.618000
#            QQQ      119.989998  118.889999  119.269997  119.540001
#            SPY      225.830002  223.880005  225.039993  225.240005
#            USO       12.000000   11.360000   11.980000   11.440000
#            VXX       98.639999   94.559998   97.919998   94.800003
# 2017-01-04 EEM       35.770000   35.610001   35.630001   35.700001
#
# Attributes              Volume   Adj Close
# Date       Symbols
# 2017-01-03 EEM      64483700.0   34.514641
#            GDX      83239600.0   21.585840
#            GLD       7527400.0  110.470001
#            IWM      29792400.0  132.576813
#            MJ           1300.0   24.495026
#            QQQ      22307600.0  117.803764
#            SPY      91366500.0  218.092178
#            USO      36183500.0   11.440000
#            VXX       9778700.0   94.800003
# 2017-01-04 EEM      83072600.0   34.777668

# %%
df.reset_index(inplace = True)
df.head(10)
# Out:
# Attributes  index       Date Symbols        High         Low        Open  \
# 0               0 2017-01-03     EEM   35.650002   35.299999   35.389999
# 1               1 2017-01-03     GDX   21.770000   20.980000   21.070000
# 2               2 2017-01-03     GLD  111.000000  109.370003  109.620003
# 3               3 2017-01-03     IWM  136.830002  134.500000  136.490005
# 4               4 2017-01-03      MJ   24.681999   24.510000   24.510000
# 5               5 2017-01-03     QQQ  119.989998  118.889999  119.269997
# 6               6 2017-01-03     SPY  225.830002  223.880005  225.039993
# 7               7 2017-01-03     USO   12.000000   11.360000   11.980000
# 8               8 2017-01-03     VXX   98.639999   94.559998   97.919998
# 9               9 2017-01-04     EEM   35.770000   35.610001   35.630001
#
# Attributes       Close      Volume   Adj Close
# 0            35.430000  64483700.0   34.514641
# 1            21.760000  83239600.0   21.585840
# 2           110.470001   7527400.0  110.470001
# 3           135.520004  29792400.0  132.576813
# 4            24.618000      1300.0   24.495026
# 5           119.540001  22307600.0  117.803764
# 6           225.240005  91366500.0  218.092178
# 7            11.440000  36183500.0   11.440000
# 8            94.800003   9778700.0   94.800003
# 9            35.700001  83072600.0   34.777668

# %% [markdown]
# #### Using the data frame of prices, we need a data frame of each stocks' returns
# so we need to do the follow:
# 1. Create a df of returns for each stock
# 2. recombine the individual stock returns dfs into one big dataframe where we can run statistical analysis

# %%
sample_df = df[df.Symbols=='GLD'].loc[:,['Date','Symbols','Adj Close','Volume']]
sample_df.set_index('Date').index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2018-10-05', '2018-10-08', '2018-10-09', '2018-10-10',
#                '2018-10-11', '2018-10-12', '2018-10-15', '2018-10-16',
#                '2018-10-17', '2018-10-18'],
#               dtype='datetime64[ns]', name='Date', length=453, freq=None)

# %%
l_col_to_keep = ['Date','Symbols','Adj Close','Volume']
l_df =[]

# List comprehension won't really work because we are trying to do a couple things for each symbols here
#l_df = [ df[df.Symbols == sym].loc[:, l_col_to_keep ] for sym in lsymbols]

for sym in lsymbols:
    i_df = df[df.Symbols == sym].loc[:, l_col_to_keep]
    i_df = i_df.set_index('Date')
    i_df[f"r({sym})"] = i_df['Adj Close']/ i_df['Adj Close'].shift(1) - 1
    i_df = i_df.dropna() #only the first record should be dropped
    l_df.append(i_df)
    
    # Optional print to double check
    #print(i_df.head(3))

# %% [markdown]
# we got each stock's return in the list object **l_df** now.
#
# Let's recombine them into a return matrix dataframe!

# %%
from functools import reduce
return_df = reduce( lambda x,y: pd.concat([x,y], axis=1),
                   [ i_df.iloc[:,-1] for i_df in l_df] )

# %%
return_df.head()
# Out:
#               r(SPY)    r(GLD)    r(EEM)    r(QQQ)    r(IWM)    r(VXX)  \
# Date
# 2017-01-04  0.005949  0.003530  0.007621  0.005437  0.016676 -0.051477
# 2017-01-05 -0.000795  0.015515  0.010924  0.005658 -0.011540 -0.003559
# 2017-01-06  0.003578 -0.007373 -0.004156  0.008770 -0.003672 -0.012054
# 2017-01-09 -0.003301  0.008233 -0.000835  0.003281 -0.006559 -0.004067
# 2017-01-10  0.000000  0.004260  0.005848  0.002207  0.009570 -0.006352
#
#               r(USO)    r(GDX)     r(MJ)
# Date
# 2017-01-04  0.012238  0.007353  0.006174
# 2017-01-05  0.010363  0.058394  0.006459
# 2017-01-06 -0.001709 -0.034914  0.002006
# 2017-01-09 -0.031678  0.003126  0.000000
# 2017-01-10 -0.021220  0.007124 -0.009688

# %% [markdown]
# #### Now we do some cool stuff!
# Let's plot the returns correlation heat map
#
# [Here](https://seaborn.pydata.org/tutorial/aesthetics.html) is some reference on how to make seaborn look sexier

# %%
correlation_matrix = return_df.corr()
plt.figure(figsize = (16,8))
sns.set_context("paper", font_scale = 1.5)
sns.heatmap(correlation_matrix,annot=True)

# %% [markdown]
# #### Let's compare two stocks return

# %%
target_syms = ['GLD', 'GDX']
sym_keys = [f"r({i})" for i in target_syms]

plt.figure(figsize = (16,8))
sns.set_context("paper", font_scale = 1.5)

reduce(lambda x,y: sns.jointplot(x, y, return_df, kind='scatter'), sym_keys)
# Out:
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(return_df)
