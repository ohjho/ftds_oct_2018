# %% [markdown]
# ## Using BeautifulSoup to Scrap Workouts
# We will scrap the [Crossfit Weightlifting Blog](http://crossfitweightlifting.com/category/wod/weightlifter/) and following this [BeautifulSoup](https://www.dataquest.io/blog/web-scraping-tutorial-python/) tutorial

# %%
import requests
from bs4 import BeautifulSoup

url= 'http://crossfitweightlifting.com/category/wod/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:60.0) Gecko/20100101 Firefox/60.0'
}
page = requests.get(url, headers = headers)

soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# #### 403 Forbidden Error
# From [this](https://stackoverflow.com/questions/38489386/python-requests-403-forbidden) it seems the page rejects `Get` requests that don't have a `User-Agent`

# %% [markdown]
# ### View the nicely format HTML
# use the `prettify` method to view the `BeautifulSoup` object

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if lt IE 7]><html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if (IE 7)&!(IEMobile)]><html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js lt-ie9 lt-ie8"><![endif]-->
# <!--[if (IE 8)&!(IEMobile)]><html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js lt-ie9"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Google Chrome Frame for IE -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    WOD Archives - CrossFit Weightlifting
#   </title>
#   <!-- mobile meta (hooray!) -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <link href="http://crossfitweightlifting.com/xmlrpc.php" rel="pingback"/>
#    <!-- wordpress head functions -->
#    <!-- This site is optimized with the Yoast SEO plugin v3.4.2 - https://yoast.com/wordpress/plugins/seo/ -->
#    <link href="http://crossfitweightlifting.com/category/wod/" rel="canonical">
#     <link href="http://crossfitweightlifting.com/category/wod/page/2/" rel="next"/>
#     <meta content="en_US" property="og:locale">
#      <meta content="object" property="og:type">
#       <meta content="WOD Archives - CrossFit Weightlifting" property="og:title">
#        <meta content="http://crossfitweightlifting.com/category/wod/" property="og:url"/>
#        <meta content="CrossFit Weightlifting" property="og:site_name"/>
#        <!-- / Yoast SEO plugin. -->
#        <link href="//s0.wp.com" rel="dns-prefetch"/>
#        <link href="//s.gravatar.com" rel="dns-prefetch"/>
#        <link href="//s.w.org" rel="dns-prefetch"/>
#        <link href="http://crossfitweightlifting.com/feed/" rel="alternate" title="CrossFit Weightlifting » Feed" type="application/rss+xml"/>
#        <link href="http://crossfitweightlifting.com/comments/feed/" rel="alternate" title="CrossFit Weightlifting » Comments Feed" type="application/rss+xml"/>
#        <link href="http://crossfitweightlifting.com/category/wod/feed/" rel="alternate" title="CrossFit Weightlifting » WOD Category Feed" type="application/rss+xml"/>
#        <script type="text/javascript">
#         window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/crossfitweightlifting.com\/wp-includes\/js\/wp-emoji-release.min.js"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
#        </script>
#        <style type="text/css">
#         img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#        </style>
#        <link href="http://crossfitweightlifting.com/wp-content/plugins/q-and-a/css/q-a-plus.css" id="q-a-plus-css" media="screen" rel="stylesheet" type="text/css"/>
#        <link href="http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/css/style.css" id="bones-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#        <!--[if lt IE 9]>
# <link rel='stylesheet' id='bones-ie-only-css'  href='http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/css/ie.css' type='text/css' media='all' />
# <![endif]-->
#        <link href="http://crossfitweightlifting.com/wp-content/plugins/jetpack/css/jetpack.css" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="http://crossfitweightlifting.com/wp-content/plugins/advanced-recent-posts-widget/css/advanced-recent-posts-widget.css" id="wp-advanced-rp-css-css" media="all" rel="stylesheet" type="text/css"/>
#        <link href="http://crossfitweightlifting.com/wp-content/plugins/slidedeck2-personal/css/slidedeck.css" id="slidedeck-css" media="screen" rel="stylesheet" type="text/css"/>
#        <link href="http://crossfitweightlifting.com/wp-content/plugins/ubermenu/standard/styles/basic.css" id="ubermenu-basic-css" media="all" rel="stylesheet" type="text/css"/>
#        <script type="text/javascript">
#         window.slideDeck2Version = "2.3.3";
# window.slideDeck2Distribution = "pro";
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-includes/js/jquery/jquery.js" type="text/javascript">
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-includes/js/jquery/jquery-migrate.min.js" type="text/javascript">
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/js/libs/modernizr.custom.min.js" type="text/javascript">
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-content/plugins/slidedeck2-personal/js/jquery-mousewheel/jquery.mousewheel.min.js" type="text/javascript">
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-content/plugins/slidedeck2-personal/js/jquery.easing.1.3.js" type="text/javascript">
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-content/plugins/slidedeck2-personal/js/slidedeck.jquery.js" type="text/javascript">
#        </script>
#        <script src="http://crossfitweightlifting.com/wp-content/plugins/slidedeck2-personal/js/slidedeck-public.js" type="text/javascript">
#        </script>
#        <script src="http://platform.twitter.com/widgets.js" type="text/javascript">
#        </script>
#        <link href="http://crossfitweightlifting.com/wp-json/" rel="https://api.w.org/"/>
#        <link href="http://crossfitweightlifting.com/wp-content/uploads/2015/06/favicon-weightlifting.png" rel="shortcut icon"/>
#        <meta content="3EqKgx-ufkOlDQRR4sVftdEGoledh6RvPErObi263h4" name="google-site-verification"/>
#        <!-- Q & A -->
#        <noscript>
#         <link href="http://crossfitweightlifting.com/wp-content/plugins/q-and-a/css/q-a-plus-noscript.css?ver=1.0.6.2" rel="stylesheet" type="text/css"/>
#        </noscript>
#        <!-- Q & A -->
#        <link href="//v0.wordpress.com" rel="dns-prefetch"/>
#        <style type="text/css">
#         img#wpstats{display:none}
#        </style>
#        <!-- Vipers Video Quicktags v6.6.0 | http://www.viper007bond.com/wordpress-plugins/vipers-video-quicktags/ -->
#        <style type="text/css">
#         .vvqbox { display: block; max-width: 100%; visibility: visible !important; margin: 10px auto; } .vvqbox img { max-width: 100%; height: 100%; } .vvqbox object { max-width: 100%; }
#        </style>
#        <script type="text/javascript">
#         // <![CDATA[
# 	var vvqflashvars = {};
# 	var vvqparams = { wmode: "opaque", allowfullscreen: "true", allowscriptaccess: "always" };
# 	var vvqattributes = {};
# 	var vvqexpressinstall = "http://crossfitweightlifting.com/wp-content/plugins/vipers-video-quicktags/resources/expressinstall.swf";
# // ]]>
#        </script>
#        <!-- BEGIN GADWP v5.1.1.1 Universal Analytics - https://deconf.com/google-analytics-dashboard-wordpress/ -->
#        <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-59345411-1', 'auto');
#   ga('send', 'pageview');
#        </script>
#        <!-- END GADWP Universal Analytics -->
#        <!-- UberMenu CSS - Controlled through UberMenu Options Panel
# ================================================================ -->
#        <style id="ubermenu-style-generator-css" type="text/css">
#         /* Image Text Padding */
# #megaMenu .ss-nav-menu-with-img > a > .wpmega-link-title, #megaMenu .ss-nav-menu-with-img > a > .wpmega-link-description, #megaMenu .ss-nav-menu-with-img > a > .wpmega-item-description, #megaMenu .ss-nav-menu-with-img > span.um-anchoremulator > .wpmega-link-title, #megaMenu .ss-nav-menu-with-img > span.um-anchoremulator > .wpmega-link-description, #megaMenu .ss-nav-menu-with-img > span.um-anchoremulator > .wpmega-item-description{
#   padding-left: 23px;
# }
#        </style>
#        <!-- end UberMenu CSS -->
#        <style id="wp-custom-css" type="text/css">
#         /*
# Welcome to Custom CSS!
#
# To learn how this works, see http://wp.me/PEmnE-Bt
# */
# .gform_wrapper {
# 	background: #F8F8F8;
# 	border: 1px solid #DDD;
# 	padding: 20px;
# }
#
# .gform_wrapper .gform_footer {
# 	border-top: 1px solid #DDD;
# 	margin-top: 30px;
# 	padding-top: 25px;
# }
#
# .gform_wrapper .gform_footer input[type="submit"] {
# 	font-size: 1.4em;
# }
#        </style>
#        <!-- end of wordpress head -->
#        <!-- drop Google Analytics Here -->
#        <!-- end analytics -->
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="archive category category-wod category-5">
#   <div id="container">
#    <header class="header" role="banner">
#     <div id="topbar">
#      <div class="wrap clearfix" id="inner-topbar">
#       <div class="twelvecol" id="social">
#        <div class="icons clearfix">
#         <ul class="socialstickers">
#          <li class="icon icon_facebook">
#           <a href="http://crossfitweightlifting.com/wp-content/plugins/social-stickers-multi/link.php?url=aHR0cDovL2ZhY2Vib29rLmNvbS9wYWdlcy9Dcm9zc2ZpdC1XZWlnaHRsaWZ0aW5nLVRyYWluZXItQ291cnNlLzExMzc1NzY2NTMxNjUwMA==&amp;network=ZmFjZWJvb2s=&amp;nonce=ZjUxMGM0OGY4Mw==" target="_blank" title="Facebook">
#            <img alt="Facebook" height="20" src="http://crossfitweightlifting.com/wp-content/plugins/social-stickers-multi/themes/default/facebook.png" width="20"/>
#           </a>
#          </li>
#          <li class="icon icon_instagram">
#           <a href="http://crossfitweightlifting.com/wp-content/plugins/social-stickers-multi/link.php?url=aHR0cDovL2luc3RhZ3JhbS5jb20vY3Jvc3NmaXRfd2VpZ2h0bGlmdGluZw==&amp;network=aW5zdGFncmFt&amp;nonce=ZjUxMGM0OGY4Mw==" target="_blank" title="Instagram">
#            <img alt="Instagram" height="20" src="http://crossfitweightlifting.com/wp-content/plugins/social-stickers-multi/themes/default/instagram.png" width="20"/>
#           </a>
#          </li>
#          <li class="like_button button_facebook">
#           <iframe allowtransparency="true" frameborder="0" scrolling="no" src="//www.facebook.com/plugins/like.php?href=http%3A%2F%2Ffacebook.com%2Fpages%2FCrossfit-Weightlifting-Trainer-Course%2F113757665316500&amp;width&amp;layout=button_count&amp;action=like&amp;show_faces=false&amp;share=true&amp;height=21&amp;appId=409745342385812" style="border:none; overflow:hidden; height:21px;">
#           </iframe>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <!-- /#social -->
#      </div>
#      <!-- /#inner-topbar -->
#     </div>
#     <div class="clearfix wrap" id="inner-header">
#      <div id="logo">
#       <div class="">
#        <a href="http://crossfitweightlifting.com/" rel="home" title="CrossFit Weightlifting">
#         <img src="http://crossfitweightlifting.com/wp-content/uploads/2015/06/logo-weightlifting1.png"/>
#        </a>
#       </div>
#      </div>
#      <nav class="top-margin twelvecol clearfix" role="navigation">
#       <div class="inner-nav wrap">
#        <div class="megaMenuContainer megaMenu-nojs megaResponsive megaResponsiveToggle wpmega-withjs megaMenuOnHover megaFullWidth megaMenuHorizontal wpmega-noconflict megaMinimizeResiduals megaResetStyles" id="megaMenu">
#         <div class="megaMenuToggle" id="megaMenuToggle">
#          Menu
#          <span class="megaMenuToggle-icon">
#          </span>
#         </div>
#         <ul class="megaMenu" id="megaUber">
#          <li class="menu-item menu-item-type-custom menu-item-object-custom ss-nav-menu-item-0 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-23">
#           <a href="/">
#            <span class="wpmega-link-title">
#             Home
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page ss-nav-menu-item-1 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-25">
#           <a href="http://crossfitweightlifting.com/about-us/">
#            <span class="wpmega-link-title">
#             About Us
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category ss-nav-menu-item-2 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-7343">
#           <a href="http://crossfitweightlifting.com/category/blog/">
#            <span class="wpmega-link-title">
#             Blog
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-menu-item ss-nav-menu-item-3 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-7342">
#           <a href="http://crossfitweightlifting.com/category/wod/">
#            <span class="wpmega-link-title">
#             WOD
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children mega-with-sub ss-nav-menu-item-4 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-3829">
#           <a href="#">
#            <span class="wpmega-link-title">
#             Seminars
#            </span>
#           </a>
#           <ul class="sub-menu sub-menu-1">
#            <li class="menu-item menu-item-type-custom menu-item-object-custom ss-nav-menu-item-depth-1" id="menu-item-3831">
#             <a href="https://training.crossfit.com/weightlifting">
#              <span class="wpmega-link-title">
#               Weightlifting Level 1 Seminars
#              </span>
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom ss-nav-menu-item-depth-1" id="menu-item-3830">
#             <a href="https://training.crossfit.com/weightlifting-level-two">
#              <span class="wpmega-link-title">
#               Weightlifting Level 2 Seminars
#              </span>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom ss-nav-menu-item-5 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-3959">
#           <a href="https://www.americanfitapparel.com/collections/crossfit-weightlifting-apparel">
#            <span class="wpmega-link-title">
#             Store
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page ss-nav-menu-item-6 ss-nav-menu-item-depth-0 ss-nav-menu-mega ss-nav-menu-mega-alignCenter" id="menu-item-30">
#           <a href="http://crossfitweightlifting.com/host-a-course/">
#            <span class="wpmega-link-title">
#             Host A Course
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <!-- end #inner-header -->
#    </header>
#    <!-- end header -->
#    <div id="content">
#     <div class="wrap clearfix" id="inner-content">
#      <div class="eightcol first clearfix" id="main" role="main">
#       <h1 class="page-title">
#        WOD
#       </h1>
#       <div class="loop">
#        <article class="clearfix post-7332 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7332" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/friday-october-26-2018-week-four-day-five/" rel="bookmark" title="Friday, October 26, 2018- Week Four- Day Five">
#            Friday, October 26, 2018- Week Four- Day Five
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-25" pubdate="">
#            October 25th, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/friday-october-26-2018-week-four-day-five/" rel="bookmark" title="Friday, October 26, 2018- Week Four- Day Five">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           Zotts Press: 3×3
#          </p>
#          <p>
#           Snatch Balance: 3,2,1,1,1
#          </p>
#          <p>
#           Behind the Neck Jerk: 5×1
#          </p>
#          <p>
#           Snatch Deadlifts: 3×3
#          </p>
#          <p>
#           Russian Twists: 3×30. Slow and Controlled.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           Hip Extensions: 3×10
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/friday-october-26-2018-week-four-day-five/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7328 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7328" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/wednesday-october-24-2018-week-four-day-three/" rel="bookmark" title="Wednesday, October 24, 2018- Week Four- Day Three">
#            Wednesday, October 24, 2018- Week Four- Day Three
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-23" pubdate="">
#            October 23rd, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/wednesday-october-24-2018-week-four-day-three/" rel="bookmark" title="Wednesday, October 24, 2018- Week Four- Day Three">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           Hang Snatch + Power Snatch: (1+1) x 3
#          </p>
#          <p>
#           Clean Pull + Clean (1+1) x 4.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           Back Squats: 3,2,1,3,2,1
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/wednesday-october-24-2018-week-four-day-three/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7330 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7330" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/thursday-october-24-2018-week-four-day-four/" rel="bookmark" title="Thursday, October 24, 2018- Week Four- Day Four">
#            Thursday, October 24, 2018- Week Four- Day Four
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-23" pubdate="">
#            October 23rd, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/thursday-october-24-2018-week-four-day-four/" rel="bookmark" title="Thursday, October 24, 2018- Week Four- Day Four">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#          </p>
#          <p>
#           REST
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/thursday-october-24-2018-week-four-day-four/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7326 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7326" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/tuesday-october-23-2018-week-four-day-two/" rel="bookmark" title="Tuesday, October 23, 2018- Week Four- Day Two">
#            Tuesday, October 23, 2018- Week Four- Day Two
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-22" pubdate="">
#            October 22nd, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/tuesday-october-23-2018-week-four-day-two/" rel="bookmark" title="Tuesday, October 23, 2018- Week Four- Day Two">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#          </p>
#          <p>
#           Push Press: 3×5. Light and Perfect!
#          </p>
#          <p>
#           Push Jerk: 3,2,1,1,1
#          </p>
#          <p>
#           Power Clean + Jerk (1+1)x2x 3 working sets.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           Clean Pulls: 3×3
#          </p>
#          <p>
#           3 Sets:
#          </p>
#          <p>
#           Weighted Planks x 30 seconds
#          </p>
#          <p>
#           KB Side Bends x 20 each side
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/tuesday-october-23-2018-week-four-day-two/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7324 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7324" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/monday-october-22-2018-week-four-day-one-slight-deload/" rel="bookmark" title="Monday, October 22, 2018- Week Four- Day One- Slight Deload">
#            Monday, October 22, 2018- Week Four- Day One- Slight Deload
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-21" pubdate="">
#            October 21st, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/monday-october-22-2018-week-four-day-one-slight-deload/" rel="bookmark" title="Monday, October 22, 2018- Week Four- Day One- Slight Deload">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           Muscle Snatch: 3,3,2,2,1,1
#          </p>
#          <p>
#           SN PP + OHS (2+2) x 3
#          </p>
#          <p>
#           Snatch: 3×3, 3×2, 3×1. Work consistency and keep the weight where you can feel fast and snappy.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           Front Squat: 5,4,3,2,1
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/monday-october-22-2018-week-four-day-one-slight-deload/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7320 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7320" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/sunday-october-21-2018-week-three-day-seven/" rel="bookmark" title="Sunday, October 21, 2018- Week Three- Day Seven">
#            Sunday, October 21, 2018- Week Three- Day Seven
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-20" pubdate="">
#            October 20th, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/sunday-october-21-2018-week-three-day-seven/" rel="bookmark" title="Sunday, October 21, 2018- Week Three- Day Seven">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/sunday-october-21-2018-week-three-day-seven/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7318 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7318" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/saturday-october-20-2018-week-three-day-six/" rel="bookmark" title="Saturday, October 20, 2018- Week Three- Day Six">
#            Saturday, October 20, 2018- Week Three- Day Six
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-19" pubdate="">
#            October 19th, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/saturday-october-20-2018-week-three-day-six/" rel="bookmark" title="Saturday, October 20, 2018- Week Three- Day Six">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           Snatch: Work up to a heavy single for the day
#          </p>
#          <p>
#           Clean and Jerk: Work up to a heavy single for the day
#          </p>
#          <p>
#           Front Squat: Work up to a heavy double in five sets.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/saturday-october-20-2018-week-three-day-six/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7316 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7316" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/friday-october-19-2018-week-three-day-five/" rel="bookmark" title="Friday, October 19, 2018- Week Three- Day Five">
#            Friday, October 19, 2018- Week Three- Day Five
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-18" pubdate="">
#            October 18th, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/friday-october-19-2018-week-three-day-five/" rel="bookmark" title="Friday, October 19, 2018- Week Three- Day Five">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           Zotts Press: 3×3
#          </p>
#          <p>
#           Snatch Balance: 3,3,2,2,2,1,1
#          </p>
#          <p>
#           Behind the Neck Jerk + Jerk: (1+1) x 5 working sets.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           DB Single Arm Waiter Walk Walking Lunge x 10 steps with right arm overhead and 10 steps with left arm overhead.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           Russian Twists: 3×30. Slow and Controlled.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/friday-october-19-2018-week-three-day-five/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7314 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7314" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/thursday-october-18-2018-week-three-day-four/" rel="bookmark" title="Thursday, October 18, 2018- Week Three- Day Four">
#            Thursday, October 18, 2018- Week Three- Day Four
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-17" pubdate="">
#            October 17th, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/thursday-october-18-2018-week-three-day-four/" rel="bookmark" title="Thursday, October 18, 2018- Week Three- Day Four">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           REST
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/thursday-october-18-2018-week-three-day-four/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <article class="clearfix post-7312 post type-post status-publish format-standard hentry category-weightlifter category-wod" id="post-7312" role="article">
#         <header class="article-header">
#          <h2 class="entry-title">
#           <a href="http://crossfitweightlifting.com/2018/10/wednesday-october-17-2018-week-three-day-three/" rel="bookmark" title="Wednesday, October 17, 2018- Week Three- Day Three">
#            Wednesday, October 17, 2018- Week Three- Day Three
#           </a>
#          </h2>
#          <p class="byline vcard">
#           Posted
#           <time class="updated" datetime="2018-10-16" pubdate="">
#            October 16th, 2018
#           </time>
#           by
#           <span class="author">
#            <a href="http://crossfitweightlifting.com/author/sageburgener/" rel="author" title="Posts by Sage Burgener">
#             Sage Burgener
#            </a>
#           </span>
#           <span class="amp">
#            &amp;
#           </span>
#           filed under
#           <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#            Weightlifter WOD
#           </a>
#           ,
#           <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#            WOD
#           </a>
#           .
#          </p>
#         </header>
#         <!-- end article header -->
#         <section class="entry-preview">
#          <a href="http://crossfitweightlifting.com/2018/10/wednesday-october-17-2018-week-three-day-three/" rel="bookmark" title="Wednesday, October 17, 2018- Week Three- Day Three">
#          </a>
#         </section>
#         <section class="entry-content clearfix">
#          <p>
#           Hang Power Snatch + Hang Snatch: (2+1) x 4
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           Power Clean from Below Knee + Push Jerk + Behind the Neck Jerk (1+1+1) x 4
#          </p>
#          <p>
#           Low Bar Back Squats: 5,3,1,5,3,1,10,8.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#          <p>
#           In between squat sets perform single leg DB Deadlifts x 10 each leg and Seated Single Arm DB Press x 10 each arm.
#           <span class="Apple-converted-space">
#           </span>
#          </p>
#         </section>
#         <!-- end article section -->
#         <footer class="article-footer">
#          <div class="entry-utility">
#           <span class="cat-links">
#            <span class="entry-utility-prep entry-utility-prep-cat-links">
#             Posted in
#            </span>
#            <a href="http://crossfitweightlifting.com/category/wod/weightlifter/" rel="category tag">
#             Weightlifter WOD
#            </a>
#            ,
#            <a href="http://crossfitweightlifting.com/category/wod/" rel="category tag">
#             WOD
#            </a>
#           </span>
#           <span class="meta-sep">
#            |
#           </span>
#           <span class="comments-link">
#            <a href="http://crossfitweightlifting.com/2018/10/wednesday-october-17-2018-week-three-day-three/#respond">
#             Leave a comment
#            </a>
#           </span>
#          </div>
#          <!-- /.entry-utility -->
#         </footer>
#         <!-- end article footer -->
#        </article>
#        <!-- end article -->
#        <nav class="page-navigation">
#         <ol class="bones_page_navi clearfix">
#          <li class="bpn-prev-link">
#          </li>
#          <li class="bpn-current">
#           <a href="#">
#            1
#           </a>
#          </li>
#          <li>
#           <a href="http://crossfitweightlifting.com/category/wod/page/2/">
#            2
#           </a>
#          </li>
#          <li>
#           <a href="http://crossfitweightlifting.com/category/wod/page/3/">
#            3
#           </a>
#          </li>
#          <li>
#           <a href="http://crossfitweightlifting.com/category/wod/page/4/">
#            4
#           </a>
#          </li>
#          <li>
#           <a href="http://crossfitweightlifting.com/category/wod/page/5/">
#            5
#           </a>
#          </li>
#          <li>
#           <a href="http://crossfitweightlifting.com/category/wod/page/6/">
#            6
#           </a>
#          </li>
#          <li>
#           <a href="http://crossfitweightlifting.com/category/wod/page/7/">
#            7
#           </a>
#          </li>
#          <li class="bpn-next-link">
#           <a href="http://crossfitweightlifting.com/category/wod/page/2/">
#            »
#           </a>
#          </li>
#          <li class="bpn-last-page-link">
#           <a href="http://crossfitweightlifting.com/category/wod/page/199/" title="Last">
#            Last
#           </a>
#          </li>
#         </ol>
#        </nav>
#       </div>
#       <!-- end .loop -->
#      </div>
#      <!-- end #main -->
#      <div class="fourcol last" id="side">
#       <div class="widget-container advanced_recent_posts_widget" id="advanced-recent-posts-2">
#        <h3 class="widget-title">
#         Recent Blog Posts
#        </h3>
#        <ul>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/complexes-and-why-we-love-them/" rel="bookmark" title="Permanent link to Complexes and Why We Love Them">
#           Complexes and Why We Love Them
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/meet-the-bar-2/" rel="bookmark" title="Permanent link to Meet The Bar!">
#           Meet The Bar!
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/09/99-lifes-problems-can-solved-lats/" rel="bookmark" title="Permanent link to 99% of Life’s Problems Can Be Solved By The Lats">
#           99% of Life’s Problems Can Be Solved By The Lats
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/09/jump-up-punch-down/" rel="bookmark" title="Permanent link to Jump up, Punch Down">
#           Jump up, Punch Down
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/08/benefits-tall-snatch-tall-clean/" rel="bookmark" title="Permanent link to Benefits of the Tall Snatch and Tall Clean">
#           Benefits of the Tall Snatch and Tall Clean
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="widget-container widget_text" id="text-2">
#        <h3 class="widget-title">
#         Questions?
#        </h3>
#        <div class="textwidget">
#         <div style="background:#111; padding:15px;">
#          <h4 style="margin:0;color:#FFF;">
#           Need help understanding part of the Workout?
#          </h4>
#          <a class="button large" href="/faqs/" style="margin:15px 0 0 0;">
#           Get Answers
#           <span>
#            »
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="widget-container advanced_recent_posts_widget" id="advanced-recent-posts-4">
#        <h3 class="widget-title">
#         CrossFit Training WODs
#        </h3>
#        <ul>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2017/06/saturday-17-june-2017/" rel="bookmark" title="Permanent link to SATURDAY-17 JUNE, 2017">
#           SATURDAY-17 JUNE, 2017
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2017/01/3796/" rel="bookmark" title="Permanent link to ">
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2016/12/saturday-december-31/" rel="bookmark" title="Permanent link to Saturday – December 31">
#           Saturday – December 31
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2016/12/friday-december-30/" rel="bookmark" title="Permanent link to Friday – December 30">
#           Friday – December 30
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2016/12/thursday-december-30/" rel="bookmark" title="Permanent link to Thursday – December 30">
#           Thursday – December 30
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="widget-container widget_text" id="text-3">
#        <h3 class="widget-title">
#         Archived Workouts
#        </h3>
#        <div class="textwidget">
#         <p>
#          We just split the Weightlifting and CrossFit Training WODs into separate blog posts.  If you're looking back for an old WOD, you may want to check the older archive.
#         </p>
#         <a class="button" href="/category/wod/">
#          Old WOD Archive
#          <span>
#           »
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="widget-container advanced_recent_posts_widget" id="advanced-recent-posts-3">
#        <h3 class="widget-title">
#         Weightlifter WODs
#        </h3>
#        <ul>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/friday-october-26-2018-week-four-day-five/" rel="bookmark" title="Permanent link to Friday, October 26, 2018- Week Four- Day Five">
#           Friday, October 26, 2018- Week Four- Day Five
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/wednesday-october-24-2018-week-four-day-three/" rel="bookmark" title="Permanent link to Wednesday, October 24, 2018- Week Four- Day Three">
#           Wednesday, October 24, 2018- Week Four- Day Three
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/thursday-october-24-2018-week-four-day-four/" rel="bookmark" title="Permanent link to Thursday, October 24, 2018- Week Four- Day Four">
#           Thursday, October 24, 2018- Week Four- Day Four
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/tuesday-october-23-2018-week-four-day-two/" rel="bookmark" title="Permanent link to Tuesday, October 23, 2018- Week Four- Day Two">
#           Tuesday, October 23, 2018- Week Four- Day Two
#          </a>
#         </li>
#         <li class="recent-post-item">
#          <a class="post-title" href="http://crossfitweightlifting.com/2018/10/monday-october-22-2018-week-four-day-one-slight-deload/" rel="bookmark" title="Permanent link to Monday, October 22, 2018- Week Four- Day One- Slight Deload">
#           Monday, October 22, 2018- Week Four- Day One- Slight Deload
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="widget-container widget_FacebookLikeBox" id="facebooklikebox-2">
#        <h3 class="widget-title">
#         Like Us on Facebook!
#        </h3>
#        <script src="http://connect.facebook.net/en_US/all.js#xfbml=1">
#        </script>
#        <fb:like-box border_color="AAAAAA" header="false" href="https://www.facebook.com/pages/Crossfit-Weightlifting-Trainer-Course/113757665316500" show_faces="true" stream="false" width="340">
#        </fb:like-box>
#       </div>
#      </div>
#     </div>
#     <!-- end #inner-content -->
#    </div>
#    <!-- end #content -->
#    <footer class="footer top-margin" role="contentinfo">
#     <div class="wrap clearfix" id="inner-footer" style="">
#      <!--<a href="/about-us/">
# 			<div class="staff fourcol">
# 				<h1>Meet The Staff</h1>
# 			</div>
# 		</a>-->
#      <a href="https://www.americanfitapparel.com/collections/crossfit-weightlifting-apparel">
#       <div class="gear twelvecol" style="text-align: center;">
#        <div class="img-wrapper">
#         <img alt="" src="http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/images/gear.png">
#         </img>
#        </div>
#        <h1>
#         Buy CrossFit Weightlifting Apparel!
#        </h1>
#       </div>
#      </a>
#     </div>
#     <!-- end #inner-footer -->
#    </footer>
#    <!-- end footer -->
#    <div id="bottombar">
#     <div class="wrap" id="inner-bottombar">
#      <a href="http://crossfit.com" target="_blank">
#       <img alt="CrossFit" src="http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/images/logo-crossfit.jpg"/>
#      </a>
#      <a href="http://journal.crossfit.com/start.tpl?version=CFJ-graphic123x63" target="_blank" title="CrossFit Journal: The Performance-Based Lifestyle Resource">
#       <img alt="CrossFit Journal: The Performance-Based Lifestyle Resource" height="63px" src="http://journal.crossfit.com/templates/images/graphic-125x63.jpg" width="125px"/>
#      </a>
#      <a href="http://poweredbyawesome.com" target="_blank" title="Powered by Awesome - Websites for Affiliates">
#       <img alt="Powered by Awesome" src="http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/images/logo-sitesasrx-sx-footer-v2.png"/>
#      </a>
#     </div>
#     <!-- end #inner-bottombar -->
#    </div>
#    <!-- end #bottombar -->
#   </div>
#   <!-- end #container -->
#   <!-- all js scripts are loaded in library/bones.php -->
#   <div style="display:none">
#   </div>
#   <script src="http://crossfitweightlifting.com/wp-content/plugins/q-and-a/js/q-a-plus.js" type="text/javascript">
#   </script>
#   <script src="http://crossfitweightlifting.com/wp-content/plugins/ubermenu/core/js/hoverIntent.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var uberMenuSettings = {"speed":"300","trigger":"hoverIntent","orientation":"horizontal","transition":"slide","hoverInterval":"20","hoverTimeout":"400","removeConflicts":"on","autoAlign":"off","noconflict":"off","fullWidthSubs":"off","androidClick":"off","iOScloseButton":"on","loadGoogleMaps":"off","repositionOnLoad":"off"};
# /* ]]> */
#   </script>
#   <script src="http://crossfitweightlifting.com/wp-content/plugins/ubermenu/core/js/ubermenu.min.js" type="text/javascript">
#   </script>
#   <script src="https://s0.wp.com/wp-content/js/devicepx-jetpack.js" type="text/javascript">
#   </script>
#   <script src="http://s.gravatar.com/js/gprofiles.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
#   </script>
#   <script src="http://crossfitweightlifting.com/wp-content/plugins/jetpack/modules/wpgroho.js" type="text/javascript">
#   </script>
#   <script src="http://crossfitweightlifting.com/wp-content/themes/LX-Weightlifting/library/js/scripts.js" type="text/javascript">
#   </script>
#   <script src="http://crossfitweightlifting.com/wp-includes/js/wp-embed.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var slideDeck2URLPath = "http://crossfitweightlifting.com/wp-content/plugins/slidedeck2-personal";
# var slideDeck2AddonsURL = "http://crossfitweightlifting.com/wp-admin/admin.php?page=slidedeck2.php/upgrades";
# var slideDeck2iframeByDefault = false;
#   </script>
#   <script async="" defer="" src="https://stats.wp.com/e-201843.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    _stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:5.3',blog:'93953353',post:'0',tz:'-7',srv:'crossfitweightlifting.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '93953353', '0' ]);
#   </script>
#  </body>
# </html>
# <!-- end page. what a ride! -->

# %% [markdown]
# ### Get the Title and Links to each `<h2 class="entry-title">`

# %%
titles = soup.find_all('h2', class_ = 'entry-title')
title_dict = {}
for entry in titles:
    title_dict[entry.find('a').text] = entry.find('a').get('href')
title_dict
# Out:
# {'Friday, October 19, 2018- Week Three- Day Five': 'http://crossfitweightlifting.com/2018/10/friday-october-19-2018-week-three-day-five/',
#  'Friday, October 26, 2018- Week Four- Day Five': 'http://crossfitweightlifting.com/2018/10/friday-october-26-2018-week-four-day-five/',
#  'Monday, October 22, 2018- Week Four- Day One- Slight Deload': 'http://crossfitweightlifting.com/2018/10/monday-october-22-2018-week-four-day-one-slight-deload/',
#  'Saturday, October 20, 2018- Week Three- Day Six': 'http://crossfitweightlifting.com/2018/10/saturday-october-20-2018-week-three-day-six/',
#  'Sunday, October 21, 2018- Week Three- Day Seven': 'http://crossfitweightlifting.com/2018/10/sunday-october-21-2018-week-three-day-seven/',
#  'Thursday, October 18, 2018- Week Three- Day Four': 'http://crossfitweightlifting.com/2018/10/thursday-october-18-2018-week-three-day-four/',
#  'Thursday, October 24, 2018- Week Four- Day Four': 'http://crossfitweightlifting.com/2018/10/thursday-october-24-2018-week-four-day-four/',
#  'Tuesday, October 23, 2018- Week Four- Day Two': 'http://crossfitweightlifting.com/2018/10/tuesday-october-23-2018-week-four-day-two/',
#  'Wednesday, October 17, 2018- Week Three- Day Three': 'http://crossfitweightlifting.com/2018/10/wednesday-october-17-2018-week-three-day-three/',
#  'Wednesday, October 24, 2018- Week Four- Day Three': 'http://crossfitweightlifting.com/2018/10/wednesday-october-24-2018-week-four-day-three/'}

# %% [markdown]
# ### Then find the link to the next page `<li class='bpn-next-link'>`

# %%
next_page_url = soup.find('li', class_ = 'bpn-next-link').find('a').get('href')
next_page_url
# Out:
# 'http://crossfitweightlifting.com/category/wod/page/2/'

# %% [markdown]
# ### Tie it all together!
# Write a function to loop thru `x` number of pages and get all the workout titles and urls in a dictionary

# %%
def GetTitleAndLinks( in_soup ):
    titles = in_soup.find_all('h2', class_ = 'entry-title')
    title_dict = {}
    for entry in titles:
        title_dict[entry.find('a').text] = entry.find('a').get('href')
    return title_dict

def GetNextPageUrl( in_soup ):
    return in_soup.find('li', class_ = 'bpn-next-link').find('a').get('href')

def GetWorkouts( pageLim = 10):
    url= 'http://crossfitweightlifting.com/category/wod/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:60.0) Gecko/20100101 Firefox/60.0'
    }
    page = requests.get(url, headers = headers)
    
    outDict = {}
    
    print(f'Begin parsing {url}...\n')
    for i in range(pageLim):
        soup = BeautifulSoup(page.content, 'html.parser')
        post_dict = GetTitleAndLinks( soup )
        next_url = GetNextPageUrl( soup )
        
        outDict = {**outDict, **post_dict}
        page = requests.get(next_url, headers = headers )
        print( f'page {i+1} of {pageLim} done.\n')

    return outDict

def GetWorkoutText(in_soup):
    return in_soup.find('section', class_ = 'entry-content').text

def PrintWorkouts( lim = 100, pageLim = 10):
    woddict = GetWorkouts( pageLim)
    print(f'Found {len(woddict)} workouts, returning text for {min(len(woddict), lim)}\n')

    lim_keys = list(woddict.keys())[:min(lim, len(woddict))]
    lim_dict = { k: woddict[k] for k in lim_keys}
    out_json = []
    for wod in lim_dict:
        wod_url = lim_dict[wod]
        wod_page = requests.get(wod_url, headers = headers )
        wod_txt = GetWorkoutText( BeautifulSoup(wod_page.content, 'html.parser'))
        print(f'{wod}\n---\n{wod_txt}\n\n')
        wod_dict = {'title': wod, 'url': lim_dict[wod], 'wod': wod_txt, 'source': 'crossfit weightlifting'}
        out_json.append(wod_dict)

    return out_json

data = PrintWorkouts(lim = 2, pageLim = 1)
# Out:
# Begin parsing http://crossfitweightlifting.com/category/wod/...
#
# page 1 of 1 done.
#
# Found 10 workouts, returning text for 2
#
# Friday, October 26, 2018- Week Four- Day Five
# ---
#
# Zotts Press: 3×3
# Snatch Balance: 3,2,1,1,1
# Behind the Neck Jerk: 5×1
# Snatch Deadlifts: 3×3
# Russian Twists: 3×30. Slow and Controlled.
# Hip Extensions: 3×10
#
#
#
# Wednesday, October 24, 2018- Week Four- Day Three
# ---
#
# Hang Snatch + Power Snatch: (1+1) x 3
# Clean Pull + Clean (1+1) x 4.
# Back Squats: 3,2,1,3,2,1

# %% [markdown]
# ## Let's insert this Stuff to a mLab NoSQL MongoDB
# [This link](https://www.mongodb.com/json-and-bson) talks about NoSQL and JSON
# [This link](https://marcobonzanini.com/2015/09/07/getting-started-with-mongodb-and-python/) talks about Python and MongoDB
# [This link](https://www.mongodb.com/blog/post/getting-started-with-python-and-mongodb) is another document on Python and MongoDB

# %%
from pymongo import MongoClient
dbuser = 'jho'
dbpwd = 'databaseM1ab'
strconnect = f'mongodb://{dbuser}:{dbpwd}@ds052837.mlab.com:52837/'
client = MongoClient(strconnect)

db = client['xccelerate_ftds3']
coll = db['crossfit_wods']

# %%
data = PrintWorkouts(10, 2)
# Out:
# Begin parsing http://crossfitweightlifting.com/category/wod/...
#
# page 1 of 2 done.
#
# page 2 of 2 done.
#
# Found 20 workouts, returning text for 10
#
# Friday, October 26, 2018- Week Four- Day Five
# ---
#
# Zotts Press: 3×3
# Snatch Balance: 3,2,1,1,1
# Behind the Neck Jerk: 5×1
# Snatch Deadlifts: 3×3
# Russian Twists: 3×30. Slow and Controlled.
# Hip Extensions: 3×10
#
#
#
# Wednesday, October 24, 2018- Week Four- Day Three
# ---
#
# Hang Snatch + Power Snatch: (1+1) x 3
# Clean Pull + Clean (1+1) x 4.
# Back Squats: 3,2,1,3,2,1
#
#
#
# Thursday, October 24, 2018- Week Four- Day Four
# ---
#
#
# REST
#
#
#
# Tuesday, October 23, 2018- Week Four- Day Two
# ---
#
#
# Push Press: 3×5. Light and Perfect!
# Push Jerk: 3,2,1,1,1
# Power Clean + Jerk (1+1)x2x 3 working sets.
# Clean Pulls: 3×3
# 3 Sets:
# Weighted Planks x 30 seconds
# KB Side Bends x 20 each side
#
#
#
# Monday, October 22, 2018- Week Four- Day One- Slight Deload
# ---
#
# Muscle Snatch: 3,3,2,2,1,1
# SN PP + OHS (2+2) x 3
# Snatch: 3×3, 3×2, 3×1. Work consistency and keep the weight where you can feel fast and snappy.
# Front Squat: 5,4,3,2,1
#
#
#
# Sunday, October 21, 2018- Week Three- Day Seven
# ---
#
#
#
#
# Saturday, October 20, 2018- Week Three- Day Six
# ---
#
# Snatch: Work up to a heavy single for the day
# Clean and Jerk: Work up to a heavy single for the day
# Front Squat: Work up to a heavy double in five sets.
#
#
#
# Friday, October 19, 2018- Week Three- Day Five
# ---
#
# Zotts Press: 3×3
# Snatch Balance: 3,3,2,2,2,1,1
# Behind the Neck Jerk + Jerk: (1+1) x 5 working sets.
# DB Single Arm Waiter Walk Walking Lunge x 10 steps with right arm overhead and 10 steps with left arm overhead.
# Russian Twists: 3×30. Slow and Controlled.
#
#
#
# Thursday, October 18, 2018- Week Three- Day Four
# ---
#
# REST
#
#
#
# Wednesday, October 17, 2018- Week Three- Day Three
# ---
#
# Hang Power Snatch + Hang Snatch: (2+1) x 4
# Power Clean from Below Knee + Push Jerk + Behind the Neck Jerk (1+1+1) x 4
# Low Bar Back Squats: 5,3,1,5,3,1,10,8.
# In between squat sets perform single leg DB Deadlifts x 10 each leg and Seated Single Arm DB Press x 10 each arm.

# %%
coll.insert_many(data)
print(coll.count())
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-69-c2203f54de45> in <module>()
# ----> 1 coll.insert_many(data)
#       2 print(coll.count())
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     751         blk = _Bulk(self, ordered, bypass_document_validation)
#     752         blk.ops = [doc for doc in gen()]
# --> 753         blk.execute(write_concern, session=session)
#     754         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     755
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     519                 self.execute_no_results(sock_info, generator)
#     520         else:
# --> 521             return self.execute_command(generator, write_concern, session)
#     522
#     523
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     344         with client._tmp_session(session) as s:
#     345             client._retry_with_session(
# --> 346                 self.is_retryable, retryable_bulk, s, self)
#     347
#     348         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1192                     session is not None and
#    1193                     server.description.retryable_writes_supported)
# -> 1194                 with self._get_socket(server) as sock_info:
#    1195                     if retryable and not supports_session:
#    1196                         if is_retrying():
#
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server)
#    1056     def _get_socket(self, server):
#    1057         try:
# -> 1058             with server.get_socket(self.__all_credentials) as sock_info:
#    1059                 yield sock_info
#    1060         except NetworkTimeout:
#
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#    1004         sock_info = self._get_socket_no_auth()
#    1005         try:
# -> 1006             sock_info.check_auth(all_credentials)
#    1007             yield sock_info
#    1008         except:
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     675
#     676             for credentials in cached - authset:
# --> 677                 auth.authenticate(credentials, self)
#     678                 self.authset.add(credentials)
#     679
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     561     mechanism = credentials.mechanism
#     562     auth_func = _AUTH_MAP.get(mechanism)
# --> 563     auth_func(credentials, sock_info)
#     564
#     565
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     538             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     539     elif sock_info.max_wire_version >= 3:
# --> 540         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     541     else:
#     542         return _authenticate_mongo_cr(credentials, sock_info)
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     260                ('payload', Binary(b"n,," + first_bare)),
#     261                ('autoAuthorize', 1)])
# --> 262     res = sock_info.command(source, cmd)
#     263
#     264     server_first = res['payload']
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     148                 helpers._check_command_response(
#     149                     response_doc, None, allowable_errors,
# --> 150                     parse_write_concern_error=parse_write_concern_error)
#     151     except Exception as exc:
#     152         if publish:
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     153
#     154             msg = msg or "%s"
# --> 155             raise OperationFailure(msg % errmsg, code, response)
#     156
#     157
#
# OperationFailure: Authentication failed.

# %% [markdown]
# ### Export to JSON

# %%
jdata = PrintWorkouts(lim = 10, pageLim = 2)
# Out:
# Begin parsing http://crossfitweightlifting.com/category/wod/...
#
# page 1 of 2 done.
#
# page 2 of 2 done.
#
# Found 20 workouts, returning text for 10
#
# Friday, October 26, 2018- Week Four- Day Five
# ---
#
# Zotts Press: 3×3
# Snatch Balance: 3,2,1,1,1
# Behind the Neck Jerk: 5×1
# Snatch Deadlifts: 3×3
# Russian Twists: 3×30. Slow and Controlled.
# Hip Extensions: 3×10
#
#
#
# Wednesday, October 24, 2018- Week Four- Day Three
# ---
#
# Hang Snatch + Power Snatch: (1+1) x 3
# Clean Pull + Clean (1+1) x 4.
# Back Squats: 3,2,1,3,2,1
#
#
#
# Thursday, October 24, 2018- Week Four- Day Four
# ---
#
#
# REST
#
#
#
# Tuesday, October 23, 2018- Week Four- Day Two
# ---
#
#
# Push Press: 3×5. Light and Perfect!
# Push Jerk: 3,2,1,1,1
# Power Clean + Jerk (1+1)x2x 3 working sets.
# Clean Pulls: 3×3
# 3 Sets:
# Weighted Planks x 30 seconds
# KB Side Bends x 20 each side
#
#
#
# Monday, October 22, 2018- Week Four- Day One- Slight Deload
# ---
#
# Muscle Snatch: 3,3,2,2,1,1
# SN PP + OHS (2+2) x 3
# Snatch: 3×3, 3×2, 3×1. Work consistency and keep the weight where you can feel fast and snappy.
# Front Squat: 5,4,3,2,1
#
#
#
# Sunday, October 21, 2018- Week Three- Day Seven
# ---
#
#
#
#
# Saturday, October 20, 2018- Week Three- Day Six
# ---
#
# Snatch: Work up to a heavy single for the day
# Clean and Jerk: Work up to a heavy single for the day
# Front Squat: Work up to a heavy double in five sets.
#
#
#
# Friday, October 19, 2018- Week Three- Day Five
# ---
#
# Zotts Press: 3×3
# Snatch Balance: 3,3,2,2,2,1,1
# Behind the Neck Jerk + Jerk: (1+1) x 5 working sets.
# DB Single Arm Waiter Walk Walking Lunge x 10 steps with right arm overhead and 10 steps with left arm overhead.
# Russian Twists: 3×30. Slow and Controlled.
#
#
#
# Thursday, October 18, 2018- Week Three- Day Four
# ---
#
# REST
#
#
#
# Wednesday, October 17, 2018- Week Three- Day Three
# ---
#
# Hang Power Snatch + Hang Snatch: (2+1) x 4
# Power Clean from Below Knee + Push Jerk + Behind the Neck Jerk (1+1+1) x 4
# Low Bar Back Squats: 5,3,1,5,3,1,10,8.
# In between squat sets perform single leg DB Deadlifts x 10 each leg and Seated Single Arm DB Press x 10 each arm.

# %%
import json
json_txt = json.dumps(jdata)
json_data = json.loads( json_txt )
fname = 'data/crossfit_wod.json'
with open(fname, 'w') as f:
    json.dump( json_data , f)
