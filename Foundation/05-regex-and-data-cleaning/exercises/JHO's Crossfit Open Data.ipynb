# %%
import pandas as pd

# %%
url_path = 'https://raw.githubusercontent.com/raybellwaves/cfanalytics/master/Data/Affiliate_list.csv'
affiliate_list = pd.read_csv(url_path)

# %%
affiliate_list.head()
# Out:
#    Unnamed: 0  Affiliate_id      Affiliate_name               Address  \
# 0           0             3    CrossFit Persist   165 Amboy Ave, #705
# 1           1             4  Far North CrossFit   17 Finlayson Street
# 2           2             5    CrossFit Dubuque  3080 Cedar Crest Ct.
# 3           3             6   Ballston CrossFit   1110 North Glebe Rd
# 4           4             8  CrossFit Moorabbin    16 Coachranes Road
#
#           City      State    Zip        Country  \
# 0  Morganville         NJ  07751  United States
# 1    Whangarei  Northland   0110    New Zealand
# 2      Dubuque         IA  52003  United States
# 3    Arlington         VA  22201  United States
# 4    Moorabbin        VIC   3189      Australia
#
#                             Website               Phone  Latitude  Longitude
# 0   http://www.crossfitpersist.com/      (732) 687-1050   40.3604   -74.2894
# 1   http://www.farnorthcrossfit.com       021 022 09234  -35.7270   174.3274
# ...

# %%
df = affiliate_list.drop(columns=['Unnamed: 0']).set_index('Affiliate_id')
df.head(3)
# Out:
#                   Affiliate_name               Address         City  \
# Affiliate_id
# 3               CrossFit Persist   165 Amboy Ave, #705  Morganville
# 4             Far North CrossFit   17 Finlayson Street    Whangarei
# 5               CrossFit Dubuque  3080 Cedar Crest Ct.      Dubuque
#
#                   State    Zip        Country  \
# Affiliate_id
# 3                    NJ  07751  United States
# 4             Northland   0110    New Zealand
# 5                    IA  52003  United States
#
#                                       Website           Phone  Latitude  \
# Affiliate_id
# 3             http://www.crossfitpersist.com/  (732) 687-1050   40.3604
# 4             http://www.farnorthcrossfit.com   021 022 09234  -35.7270
# 5                 http://crossfitdubuque.com/  (563) 552-8423   42.4787
#
#               Longitude
# Affiliate_id
# 3              -74.2894
# 4              174.3274
# 5              -90.7068

# %%
grouped = df.groupby('Country')['Affiliate_name'].agg({'Affiliate_count':'count'})
grouped.sort_values(by = 'Affiliate_count', ascending = False)
# Out:
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#                                        Affiliate_count
# Country
# United States                                     7326
# Brazil                                            1026
# Australia                                          610
# Italy                                              606
# Canada                                             584
# United Kingdom                                     544
# France                                             410
# Spain                                              406
# Germany                                            299
# Korea, Republic of                                 219
# Netherlands                                        216
# ...

# %%
df_us = df[df.Country=='United States']
g_df_us = df_us.groupby('State')['Affiliate_name'].agg({'Affiliate_count':'count'})
g_df_us.sort_values(by = 'Affiliate_count', ascending =False)
# Out:
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#        Affiliate_count
# State
# CA                 884
# TX                 693
# FL                 473
# NY                 293
# GA                 261
# NC                 260
# IL                 254
# PA                 228
# CO                 225
# OH                 218
# WA                 215
# VA                 197
# MA                 195
# NJ                 184
# MI                 161
# AZ                 150
# OR                 139
# TN                 137
# LA                 128
# MO                 119
# NV                 119
# SC                 111
# CT                 110
# AL                 110
# IN                 108
# MN                 107
# MD                 105
# WI                 104
# OK                  99
# KY                  92
# ...

# %%
df_ca = df[df.Country=='Canada']
g_df_ca = df_ca.groupby('State')['Affiliate_name'].agg({'Affiliate_count':'count'})
g_df_ca.sort_values(by = 'Affiliate_count', ascending =False)
# Out:
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#        Affiliate_count
# State
# ON                 204
# QC                 117
# BC                  95
# AB                  77
# SK                  29
# MB                  18
# NS                  18
# NB                  16
# PE                   6
# NL                   3
# YT                   1

# %%
df_ch = df[df.Country=='C']
g_df_ch = df_ca.groupby('State')['Affiliate_name'].agg({'Affiliate_count':'count'})
g_df_ch.sort_values(by = 'Affiliate_count', ascending =False)
# Out:
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#        Affiliate_count
# State
# ON                 204
# QC                 117
# BC                  95
# AB                  77
# SK                  29
# MB                  18
# NS                  18
# NB                  16
# PE                   6
# NL                   3
# YT                   1

# %%
df_ch = df[(df.Country=='China') | (df.Country == 'Hong Kong') | (df.Country == 'Macau')]
g_df_ch = df_ch.groupby('State')['Affiliate_name'].agg({'Affiliate_count':'count'})
g_df_ch.sort_values(by = 'Affiliate_count', ascending =False)
# Out:
# /Users/JHO/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#                     Affiliate_count
# State
# Beijing                          22
# Shanghai                         16
# Zhejiang                         14
# Guangdong                        13
# Jiangsu                          10
# Fujian                            5
# Guangdong Province                5
# Sichuan                           4
# Shaanxi                           4
# Hong Kong                         4
# Neimenggu A. R.                   4
# Hunan                             4
# Shandong                          4
# Hubei                             4
# GuangDong                         3
# Chongqing                         3
# JiangSu                           2
# Zhejiang Province                 2
# Liaoning                          2
# ...
