# %% [markdown]
# <h1 style="font-size:42px; text-align:center; margin-bottom:30px;"><span style="color:SteelBlue">Module 4:</span> Cluster Analysis</h1>
# <hr>
#
#
# At last, it's time to build our clustering models!
#
#
# For clustering problems, the chosen input features are usually more important than which algorithm you use.
# * In this module, we'll apply the K-Means algorithm to 3 different feature sets.
# * There are no clear, widely-accepted performance metrics for clusters because there're no "ground truth" labels.
# * Even so, we can compare the different clusters created from the 3 different feature sets.
#
# <br><hr id="toc">
#
# ### In this module, we will cover...
#
# 1. K-Means
# 2. Base feature
# 3. Threshold features
# 4. PCA features
# 5. Model comparison

# %% [markdown]
# ### First, let's import libraries and load the datasets.
#
# First, import libraries that you'll need.

# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
# Import analytical base table
base_df = pd.read_csv('data/analytical_base.csv', index_col=0)

# Import thresholded item features
threshold_item_data = pd.read_csv('data/threshold_item_data.csv', index_col=0)

# Import PCA item features
pca_item_data = pd.read_csv('data/pca_item_data.csv', index_col=0)

# %%
print(base_df.shape)
print(threshold_item_data.shape)
print(pca_item_data.shape)
# Out:
# (414, 8)
# (414, 20)
# (414, 125)

# %% [markdown]
# # 1. K-Means
#
# For clustering, which algorithm you choose is typically less important than the **input features** that you feed into it.

# %% [markdown]
# <span id="k-means"></span>
# # 1. K-Means
#
# For clustering, which algorithm you choose is typically less important than the **input features** that you feed into it.
#
# <br>
# **We already have a <code style="color:steelblue">base_df</code>.**
#
# **Create a <code style="color:steelblue">threshold_df</code> by joining it with <code style="color:steelblue">threshold_item_data</code>.**
# * Then, display the first 5 rows of the new dataframe.

# %% [markdown]
# Q1: We already have a base_df.
# Create a threshold_df by joining it with threshold_item_data.
# Then, display the first 5 rows of the new dataframe.

# %%
# Your answer here:

threshold_df = pd.concat([base_df, threshold_item_data], axis = 1)
threshold_df.head()
# Out:
#             total_transaction  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value  POST  22326  ...    20725  23084  20750  20719  \
# CustomerID                               ...
# 12347              1294.32     0      0  ...        0      3      0      4
# 12348               892.80     4      0  ...        0      0      0      0
# 12349              1757.55     1      1  ...        0      0      0      0
# 12350               334.40     1      0  ...        0      0      0      0
# 12352               840.30     5      0  ...        0      0      0      0
#
#             20726  85099B  21080  22139  22630  22961
# CustomerID
# 12347           0       0      0      0      0      0
# 12348           0       0      0      0      0      0
# 12349           0       0      0      0      0      0
# 12350           0       0      0      0      0      0
# 12352           0       0      0      0      1      0
#
# [5 rows x 28 columns]

# %%
# %load solution/m4q1.py

# %%
threshold_df.head()
# Out:
#             total_transcation  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value  22961  22630  ...   21212  22551  22629  22328  \
# CustomerID                                ...
# 12347              1294.32      0      0  ...       0      0      0      0
# 12348               892.80      0      0  ...       0      0      0      0
# 12349              1757.55      0      0  ...       0      0      0      0
# 12350               334.40      0      0  ...       0      1      0      0
# 12352               840.30      0      1  ...       0      0      0      0
#
#             21731  22556  22554  22423  22326  POST
# CustomerID
# 12347           5      0      0      4      0     0
# 12348           0      0      0      0      0     4
# 12349           0      1      1      1      1     1
# 12350           0      0      0      0      0     1
# 12352           1      0      0      2      0     5
#
# [5 rows x 28 columns]

# %%
pca_df = base_df.join(pca_item_data)

# %% [markdown]
# Q2: We already have a base_df.
# Create a pca_df by joining base_df with pca_item_data.
# Then, display the first 5 rows of the new dataframe.

# %%
# Your answer here:
pca_df = pd.concat( [base_df, pca_item_data], axis = 1)
pca_df.head()
# Out:
#             total_transaction  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value       PC1       PC2    ...        PC116     PC117  \
# CustomerID                                        ...
# 12347              1294.32  5.876139  4.828926    ...    -0.452940 -0.296131
# 12348               892.80 -4.219833  1.226232    ...     0.180772 -0.794541
# 12349              1757.55 -1.260836  2.387735    ...    -0.463174  3.172681
# 12350               334.40 -4.929319 -0.714881    ...     0.032329 -0.655412
# 12352               840.30 -2.053111  2.110533    ...    -4.037379 -8.531206
#
#                PC118     PC119     PC120     PC121     PC122     PC123  \
# CustomerID
# 12347       0.158894 -0.386851 -0.367182  0.166659  0.156405 -0.367226
# 12348       0.062513  0.393138  1.873893 -1.280147 -1.193823  1.909914
# 12349       0.070485  1.231989 -0.120768 -2.766994  0.220913 -7.212996
# 12350       1.351142 -0.827022  1.160707  0.620264  0.437828 -0.683128
# 12352      -6.517592  2.661958 -2.718597  8.759306  1.858032  1.834690
#
#                PC124     PC125
# CustomerID
# 12347       0.495659 -0.098097
# 12348      -0.915270  0.331037
# 12349       0.711504  1.357779
# 12350      -0.861502 -0.250593
# 12352      -4.596705  1.972465
#
# [5 rows x 133 columns]

# %%
# %load solution/m4q2.py

# %%
pca_df.head()
# Out:
#             total_transcation  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value       PC1       PC2    ...        PC116     PC117  \
# CustomerID                                        ...
# 12347              1294.32  5.876139  4.828897    ...     0.673156  0.392631
# 12348               892.80 -4.219846  1.226237    ...    -0.118316 -1.032854
# 12349              1757.55 -1.260855  2.387718    ...     4.283059  2.015931
# 12350               334.40 -4.929322 -0.714840    ...    -1.087437 -0.013746
# 12352               840.30 -2.053122  2.110746    ...     1.407932 -7.286822
#
#                PC118      PC119     PC120     PC121     PC122     PC123  \
# CustomerID
# 12347      -0.317756   0.470647 -0.394702 -0.471497 -0.198882 -0.801738
# 12348       0.962994  -1.629979  0.743837  1.857946  0.098048  0.020816
# 12349      -3.273682  -1.512987 -0.651950 -6.855076  0.485219  1.125110
# 12350      -1.407764  -0.488357  0.835466 -0.261455 -0.628040  0.116134
# 12352       1.590456  13.908656  1.050341  3.710750  3.241232 -4.918702
#
#                PC124     PC125
# CustomerID
# 12347       0.156484  0.471712
# 12348      -0.136735  0.941108
# 12349       2.392421 -1.476412
# 12350      -1.138599  0.002057
# 12352      -0.889066 -8.264000
#
# [5 rows x 133 columns]

# %%
# using k-mean clustering 
from sklearn.cluster import KMeans

# %% [markdown]
# # 2. Base DF
#
# The first set of features we'll consider is **"Base DF"**.
# * This only includes the purchase pattern features from our analytical base table.

# %%
base_df.head()
# Out:
#             total_transcation  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value
# CustomerID
# 12347              1294.32
# 12348               892.80
# 12349              1757.55
# 12350               334.40
# 12352               840.30

# %% [markdown]
# Let's initialize a model pipeline for K-Means.
#
# Note that we can control the number of clusters using n_clusters=3. This is the hyperparameter k
#
# We also set random_state=123 for replicable results.

# %% [markdown]
# ### JHO's notes
# #### Understanding Pipeline & Make Pipeline
# [Pipeline Kaggle Notebook](https://www.kaggle.com/baghern/a-deep-dive-into-sklearn-pipelines#)
# [Signal to Noise tutorial](https://signal-to-noise.xyz/post/sklearn-pipeline/)

# %%
k_means = make_pipeline(StandardScaler(), KMeans(n_clusters=3, random_state=123))

# %%
k_means.fit(base_df)
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('kmeans', KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=123, tol=0.0001, verbose=0))])

# %%
base_df['cluster'] = k_means.predict(base_df)

# %%
base_df.head()
# Out:
#             total_transaction  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value  cluster
# CustomerID
# 12347              1294.32        1
# 12348               892.80        0
# 12349              1757.55        0
# 12350               334.40        0
# 12352               840.30        0

# %%
base_df[['total_sales','avg_cart_value','cluster']].sample(5)
# Out:
#             total_sales  avg_cart_value  cluster
# CustomerID
# 12521            599.68         599.680        0
# 12512            138.03          69.015        0
# 12798           6977.04        2325.680        2
# 12402            225.60         225.600        0
# 12429           3750.40         937.600        0

# %% [markdown]
# To visualize these clusters, we can plot a scatterplot and color the points by cluster.
#
# Since it's impossible to visualize all of the features, we'll just pick 2.
#
# We use the hue= argument to color by cluster.

# %%
sns.lmplot(x='total_sales', y='avg_cart_value', hue='cluster', data=base_df, fit_reg=False)

# %% [markdown]
# # Threshold DF
#
# The second set of features we'll consider is **"Threshold DF"**.
# * This includes the purchase pattern features from our analytical base table.
# * This also includes the purchase counts for the 20 most popular items.

# %% [markdown]
# Q3: Initialize a new model pipeline for K-Means. Set it to create 3 clusters. Also set random_state=123 for replicable results.

# %%
# Your answer here:
kmeans_pipe = make_pipeline( StandardScaler(), KMeans(n_clusters= 3, random_state=123))
kmeans_pipe.fit( threshold_df)
threshold_df['cluster'] = kmeans_pipe.predict( threshold_df)
threshold_df.head()
# Out:
#             total_transaction  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value  POST  22326   ...     23084  20750  20719  20726  \
# CustomerID                                ...
# 12347              1294.32     0      0   ...         3      0      4      0
# 12348               892.80     4      0   ...         0      0      0      0
# 12349              1757.55     1      1   ...         0      0      0      0
# 12350               334.40     1      0   ...         0      0      0      0
# 12352               840.30     5      0   ...         0      0      0      0
#
#             85099B  21080  22139  22630  22961  cluster
# CustomerID
# 12347            0      0      0      0      0        0
# 12348            0      0      0      0      0        2
# 12349            0      0      0      0      0        2
# 12350            0      0      0      0      0        2
# 12352            0      0      0      1      0        2
#
# [5 rows x 29 columns]

# %%
# %load solution/m4q3.py

# %%
threshold_df.head()
# Out:
#             total_transcation  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value  22961  22630   ...     22551  22629  22328  21731  \
# CustomerID                                 ...
# 12347              1294.32      0      0   ...         0      0      0      5
# 12348               892.80      0      0   ...         0      0      0      0
# 12349              1757.55      0      0   ...         0      0      0      0
# 12350               334.40      0      0   ...         1      0      0      0
# 12352               840.30      0      1   ...         0      0      0      1
#
#             22556  22554  22423  22326  POST  cluster
# CustomerID
# 12347           0      0      4      0     0        0
# 12348           0      0      0      0     4        2
# 12349           1      1      1      1     1        2
# 12350           0      0      0      0     1        2
# 12352           0      0      2      0     5        2
#
# [5 rows x 29 columns]

# %%
sns.lmplot(x='total_sales', y='avg_cart_value', hue='cluster', data=threshold_df, fit_reg=False)

# %% [markdown]
# # PCA DF
#
# The last set of features we'll consider is **"PCA DF"**.
# * This includes the purchase pattern features from our analytical base table.
# * This also includes the first 125 principal component features from the item data.
#
# We'll repeat the same steps as above.

# %% [markdown]
# Q4: Initialize a new model pipeline for K-Means. Set it to create 3 clusters. Also set random_state=123 for replicable results.

# %%
# Your answer here:
kmeans_pipe.fit( pca_df)
pca_df['cluster'] = kmeans_pipe.predict(pca_df)
pca_df.head()
# Out:
#             total_transaction  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value       PC1       PC2   ...        PC117     PC118  \
# CustomerID                                       ...
# 12347              1294.32  5.876139  4.828926   ...    -0.296131  0.158894
# 12348               892.80 -4.219833  1.226232   ...    -0.794541  0.062513
# 12349              1757.55 -1.260836  2.387735   ...     3.172681  0.070485
# 12350               334.40 -4.929319 -0.714881   ...    -0.655412  1.351142
# 12352               840.30 -2.053111  2.110533   ...    -8.531206 -6.517592
#
#                PC119     PC120     PC121     PC122     PC123     PC124  \
# CustomerID
# 12347      -0.386851 -0.367182  0.166659  0.156405 -0.367226  0.495659
# 12348       0.393138  1.873893 -1.280147 -1.193823  1.909914 -0.915270
# 12349       1.231989 -0.120768 -2.766994  0.220913 -7.212996  0.711504
# 12350      -0.827022  1.160707  0.620264  0.437828 -0.683128 -0.861502
# 12352       2.661958 -2.718597  8.759306  1.858032  1.834690 -4.596705
#
#                PC125  cluster
# CustomerID
# 12347      -0.098097        0
# 12348       0.331037        1
# 12349       1.357779        1
# 12350      -0.250593        1
# 12352       1.972465        1
#
# [5 rows x 134 columns]

# %%
# %load solution/m4q4.py

# %%
pca_df.head()
# Out:
#             total_transcation  total_product  total_unique_product  \
# CustomerID
# 12347                       7            182                   103
# 12348                       4             31                    22
# 12349                       1             73                    73
# 12350                       1             17                    17
# 12352                       8             85                    59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_value       PC1       PC2   ...        PC117     PC118  \
# CustomerID                                       ...
# 12347              1294.32  5.876139  4.828897   ...     0.392631 -0.317756
# 12348               892.80 -4.219846  1.226237   ...    -1.032854  0.962994
# 12349              1757.55 -1.260855  2.387718   ...     2.015931 -3.273682
# 12350               334.40 -4.929322 -0.714840   ...    -0.013746 -1.407764
# 12352               840.30 -2.053122  2.110746   ...    -7.286822  1.590456
#
#                 PC119     PC120     PC121     PC122     PC123     PC124  \
# CustomerID
# 12347        0.470647 -0.394702 -0.471497 -0.198882 -0.801738  0.156484
# 12348       -1.629979  0.743837  1.857946  0.098048  0.020816 -0.136735
# 12349       -1.512987 -0.651950 -6.855076  0.485219  1.125110  2.392421
# 12350       -0.488357  0.835466 -0.261455 -0.628040  0.116134 -1.138599
# 12352       13.908656  1.050341  3.710750  3.241232 -4.918702 -0.889066
#
#                PC125  cluster
# CustomerID
# 12347       0.471712        0
# 12348       0.941108        2
# 12349      -1.476412        2
# 12350       0.002057        2
# 12352      -8.264000        2
#
# [5 rows x 134 columns]

# %%
sns.lmplot(x='total_sales', y='avg_cart_value', hue='cluster', data=pca_df, fit_reg=False)

# %% [markdown]
# # Model comparison
#
# Each of those 3 dataframes have the same indices:

# %%
print( all( base_df.index == threshold_df.index ) )
print( all( base_df.index == pca_df.index) )
# Out:
# True
# True

# %%
from sklearn.metrics import adjusted_rand_score

# %%
adjusted_rand_score(base_df.cluster, threshold_df.cluster)
# Out:
# 0.7512254397738608

# %%
adjusted_rand_score(threshold_df.cluster, base_df.cluster)
# Out:
# 0.7512254397738608

# %%
adjusted_rand_score(base_df.cluster, pca_df.cluster)
# Out:
# 0.8977446011520678

# %% [markdown]
# Finally, display the adjusted Rand index between base_df.cluster and pca_df.cluster.
#
# Is it higher or lower than the one between base_df.cluster and threshold_df.cluster?
#
# Which clusters are more like the ones created from the the base dataframe?

# %% [markdown]
# ## Summary of Module 4
#
# Congratulations!
#
# As a reminder, here are a few things you did in this module:
# * You brought together all of the customer-level features you've created in this project.
# * You learned the inuitition behind the K-Means algorithm.
# * You applied the K-Means algorithm to 3 different feature sets.
# * And you compared the consensus (or lack thereof) of the clusters created.

# %% [markdown]
# ## JHO's Notes
# ### Optional: what's the optimal number of clusters?
# Use the [elbow method](https://www.linkedin.com/pulse/finding-optimal-number-clusters-k-means-through-elbow-asanka-perera/)

# %%
wcss = [] # the cluster sum of errors

for i in range(1,11): # 1 to 10 clusters
    k_means = KMeans(n_clusters= i , random_state = 420)
    k_means.fit( base_df )
    wcss.append( k_means.inertia_)
    
plt.scatter(x = range(1,11), y = wcss) #looks like 3 is the optimized number of clusters
#plt.ylim(0, 11)
#plt.xlim(0, 11)

plt.xlabel('number of Clusters')
plt.ylabel('cluster sum of errors');
