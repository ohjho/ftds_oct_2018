# %% [markdown]
# ### Reference
# [Geolocation clustering a Paris Vacation](https://towardsdatascience.com/using-unsupervised-learning-to-plan-a-paris-vacation-geo-location-clustering-d0337b4210de): used K-Means and recommended HDBSCAN
# [KMeans Clustering of Geolocation](https://www.kaggle.com/xxing9703/kmean-clustering-of-latitude-and-longitude#)

# %%
import requests, json # for getting data
from urllib.parse import urlencode
from time import sleep
from datetime import datetime

import pandas as pd
import numpy as np

# %%
fname = 'data/centadata_clean.csv'
data = pd.read_csv( fname, index_col = 0 )

# %%
addresses = data['buildingaddress'].unique()

# %%
print( f'There are {"{:,}".format(len(addresses))} building addresses to lookup.')
geo_dict = { key : '' for key in addresses}
# Out:
# There are 9,496 building addresses to lookup.

# %%
def geocode( in_address, giveLatLon = True):
    url = "https://www.als.ogcio.gov.hk/lookup"
    headers = { 'Accept': 'application/json'}
    params = {
        "q": in_address,
        'n': 1
    }
    data = requests.post(url, headers = headers, data = params)
    
    if data.status_code == 200:
        djson = json.loads( data.text )
        
        try:
            geodata = djson['SuggestedAddress'][0]['Address']['PremisesAddress']['GeospatialInformation'][0]
        except KeyError:
            # no likely no SuggestedAddress
            return None
        
        if giveLatLon:
            return ( float(geodata['Latitude']), float(geodata['Longitude']))
        else:
            geodata
    else:
        return None

# %%
# ----------------------------
# ref: https://gist.github.com/vladignatyev/06860ec2040cb497f0f3
# ----------------------------
import sys

def progress(count, total, status=''):
    bar_len = 60
    filled_len = int(round(bar_len * count / float(total)))

    percents = round(100.0 * count / float(total), 1)
    bar = '=' * filled_len + '-' * (bar_len - filled_len)

    sys.stdout.write('[%s] %s%s ...%s\r' % (bar, percents, '%', status))
    sys.stdout.flush()

# %%
def BuildGeoDict( geo_dict , tmp_fname = None ):
    counter = 0

    for addr in geo_dict:
        if geo_dict[ addr ] == '':
            try:
                counter += 1
                igcode = geocode( addr)
                if igcode:
                    geo_dict[addr] = igcode

                if counter % 50 == 0:
                    # take a break every 50 address
                    progress( counter, len(geo_dict), status = 'Geocoding Building Addresses')
                    rest_s = np.random.randint(1,5)
                    sleep( rest_s)
                    
                    # make a backup
                    if tmp_fname != None:
                        with open( tmp_fname, 'w') as outfile:
                            json.dump(geo_dict, outfile)

            except ValueError:    # this will catch all exceptions
                print(f'Unexpected error coding {addr}: {sys.exc_info()[0]}\nContinuing with next address...')
        else:
            pass
    
    progress( 100, 100, status = 'Geocoding Completed.')
    print( f'Fetched {counter} buildings geocodes and written temporary json data to {tmp_fname}')
    return geo_dict

# %% [markdown]
# *Legacy*: read data from CSV

# %%
fname_csv = 'data/building_geocode.csv'
tmp_fname = 'data/tmp_building_geocode.json'
df_tmp = pd.read_csv( fname_csv, index_col = 0)

df_tmp['latlon'] = df_tmp.apply( lambda x: '' if np.isnan(x.Lat) else (x.Lat, x.Lon),axis =1)
addr_geo_dict = { key : latlon for key, latlon in zip( df_tmp.index, df_tmp.latlon ) }

fname_json = 'data/building_geocode.json'
with open( fname_json, 'w') as fh:
    json.dump( addr_geo_dict, fh)

# %% [markdown]
# Load what we already have in `data/building_geocode.json` and finish getting geocode,
# write the output in the end back to the json file

# %%
fname_json = 'data/building_geocode.json'
tmp_fname = 'data/tmp_building_geocode.json'

with open(fname_json, 'r') as fh:
    jdata = fh.read()
addr_geo_dict = json.loads(jdata)

out_dict = BuildGeoDict( addr_geo_dict, tmp_fname = tmp_fname)
with open( fname_json, 'w') as fh:
    json.dump( out_dict, fh)
# Out:
# [============================================================] 100.0% ...Geocoding Completed.dresses

# %% [markdown]
# Load the JSON back into a Dataframe for use

# %%
clean_dict = {key : tuple( out_dict[key]) for key in out_dict}
df_geo = pd.DataFrame.from_dict(clean_dict, orient = 'index', columns = ['Lat', 'Lon'])

missing_addr = df_geo[ df_geo.Lat.isna()]
print(f'There are {len(missing_addr)} buildings missing geocode.')

missing_addr.head()
# Out:
# There are 19 buildings missing geocode.
#                                         Lat  Lon
# 21 FAIRVIEW PARK SECTION C, 6TH STREET  NaN  NaN
# 11 FAIRVIEW PARK SECTION C, 6TH STREET  NaN  NaN
# 16 FAIRVIEW PARK SECTION B, 6TH STREET  NaN  NaN
# 3 FAIRVIEW PARK SECTION C, 1ST STREET   NaN  NaN
# 7 FAIRVIEW PARK SECTION C, 1ST STREET   NaN  NaN

# %% [markdown]
# Let's manually geocode these few missing geocode

# %%
import re
def manualGeo( addr ):
    m = re.search(r'(.+)SECTION', addr)
    if m is None:
        return None
    else:
        new_addr = m.group(1)
        return geocode(new_addr)

df_bgeo = df_geo.reset_index().rename(columns = {'index': 'building_address'})
df_bgeo['latlon'] = df_bgeo.apply(
     lambda x: manualGeo( x.building_address ) if np.isnan(x.Lat) else (x.Lat, x.Lon), axis=1)

#df_bgeo.at[df_bgeo.Lat.isna(),['Lat']] = df_bgeo[df_geo.Lat.isna()]['building_address'].apply( manualGeo)

# %%
df_bgeo.iloc[7515:,:].head(10)
# Out:
#                             building_address      Lat       Lon  \
# 7515  21 FAIRVIEW PARK SECTION C, 6TH STREET      NaN       NaN
# 7516  11 FAIRVIEW PARK SECTION C, 6TH STREET      NaN       NaN
# 7517  16 FAIRVIEW PARK SECTION B, 6TH STREET      NaN       NaN
# 7518   3 FAIRVIEW PARK SECTION C, 1ST STREET      NaN       NaN
# 7519  36 FAIRVIEW PARK SECTION B, 4TH STREET  22.2250  114.1120
# 7520  23 FAIRVIEW PARK SECTION C, 3RD STREET  22.2040  114.0323
# 7521   7 FAIRVIEW PARK SECTION C, 1ST STREET      NaN       NaN
# 7522  31 FAIRVIEW PARK SECTION C, 4TH STREET  22.4652  114.1425
# 7523   2 FAIRVIEW PARK SECTION B, 1ST STREET      NaN       NaN
# 7524  14 FAIRVIEW PARK SECTION C, 6TH STREET      NaN       NaN
#
#                    latlon
# 7515   (22.479, 114.0508)
# 7516  (22.4807, 114.0508)
# 7517  (22.4796, 114.0504)
# 7518  (22.4849, 114.0445)
# 7519    (22.225, 114.112)
# 7520   (22.204, 114.0323)
# 7521   (22.4746, 114.043)
# 7522  (22.4652, 114.1425)
# 7523   (22.485, 114.0444)
# 7524  (22.4795, 114.0503)

# %%
for addr in clean_dict:
    if clean_dict[addr] == ():
        clean_dict[addr] = manualGeo(addr)
        
data['latlon'] = data.buildingaddress.apply( lambda x: clean_dict[x])

# %%
data.head()
# Out:
#        txdate     price  saleablearea     xaxis yaxis  \
# 0  2017-02-16   2880000         392.0  NO. 205A   2/F
# 1  2018-01-11   3000000         392.0  NO. 205A   3/F
# 2  2017-06-26  51000000        1912.0    NO. 4B   5/F
# 3  2018-03-21   4150000         294.0    FLAT B  16/F
# 4  2017-11-28   5250000         530.0    FLAT B   8/F
#
#                  buildingaddress dateofcompletion  numberofunits  \
# 0          205A TUNG CHOI STREET       1963-08-01              8
# 1          205A TUNG CHOI STREET       1963-08-01              8
# 2  4A-4B WONG NAI CHUNG GAP ROAD       1965-09-01              8
# 3            98 TSEUK LUK STREET       1999-01-01             30
# 4          54-58 SOUTH WALL ROAD       1969-10-01             32
#
#    numberoffloors  flatsperfloor schoolnet                       region  \
# 0               8              1  九龍區32號校網             Mongkok/Yaumatei
# 1               8              1  九龍區32號校網             Mongkok/Yaumatei
# 2               8              1  香港區12號校網  Happy Valley/Mid Level East
# 3              15              2  九龍區43號校網    Diamond Hill/Wong Tai Sin
# 4               9              4  九龍區41號校網    Diamond Hill/Wong Tai Sin
#
#    price_per_sqf flat_type  floor_number  building_age  deal_age  deal_year  \
# 0    7346.938776         n             2     55.301848       641       2017
# 1    7653.061224         n             3     55.301848       312       2018
# 2   26673.640167         n             5     53.215606       511       2017
# 3   14115.646259         n            16     19.882272       243       2018
# 4    9905.660377         n             8     49.133470       356       2017
#
#                                schoolnet_en               latlon
# 0    Kowloon district No. 32 school network  (22.3231, 114.1696)
# 1    Kowloon district No. 32 school network  (22.3231, 114.1696)
# 2  Hong Kong District No. 12 school network  (22.2629, 114.1854)
# 3    Kowloon district No. 43 school network   (22.335, 114.1975)
# 4    Kowloon district No. 41 school network  (22.3298, 114.1911)

# %% [markdown]
# ### Let's build a model
#
# for our model we will just be concerned with the **small/ medium units**, and excluding all ab-normal `flat_type`

# %%
cci_data = pd.read_csv('data/cci_small_medium_2017_2018.csv', header = None, names = ['Date', 'CCI'])
cci_data['idx_date'] = cci_data['Date'].apply( lambda x: x.split(" - ")[0])

cci_data.idx_date = cci_data.idx_date.astype('datetime64')
data.txdate = data.txdate.astype('datetime64')

cci_data.head()
# Out:
#                       Date     CCI   idx_date
# 0  2018/11/05 - 2018/11/11  180.78 2018-11-05
# 1  2018/10/29 - 2018/11/04  183.32 2018-10-29
# 2  2018/10/22 - 2018/10/28  184.49 2018-10-22
# 3  2018/10/15 - 2018/10/21  185.66 2018-10-15
# 4  2018/10/08 - 2018/10/14  186.00 2018-10-08

# %%
def GetCCI(inDate):
    dfilter = (cci_data.idx_date <= inDate) 
    return cci_data[dfilter]['CCI'].iloc[0]

#GetCCI( data.txdate[1])
# Out:
# 167.47

# %%
data['adj_price_per_sqf'] = data.apply( lambda x: x.price_per_sqf * GetCCI(datetime.today())/ GetCCI(x.txdate) , axis = 1)
data.head()
# Out:
#       txdate     price  saleablearea     xaxis yaxis  \
# 0 2017-02-16   2880000         392.0  NO. 205A   2/F
# 1 2018-01-11   3000000         392.0  NO. 205A   3/F
# 2 2017-06-26  51000000        1912.0    NO. 4B   5/F
# 3 2018-03-21   4150000         294.0    FLAT B  16/F
# 4 2017-11-28   5250000         530.0    FLAT B   8/F
#
#                  buildingaddress dateofcompletion  numberofunits  \
# 0          205A TUNG CHOI STREET       1963-08-01              8
# 1          205A TUNG CHOI STREET       1963-08-01              8
# 2  4A-4B WONG NAI CHUNG GAP ROAD       1965-09-01              8
# 3            98 TSEUK LUK STREET       1999-01-01             30
# 4          54-58 SOUTH WALL ROAD       1969-10-01             32
#
#    numberoffloors  flatsperfloor        ...         \
# 0               8              1        ...
# 1               8              1        ...
# 2               8              1        ...
# 3              15              2        ...
# 4               9              4        ...
#
#                         region price_per_sqf  flat_type floor_number  \
# 0             Mongkok/Yaumatei   7346.938776          n            2
# 1             Mongkok/Yaumatei   7653.061224          n            3
# 2  Happy Valley/Mid Level East  26673.640167          n            5
# 3    Diamond Hill/Wong Tai Sin  14115.646259          n           16
# 4    Diamond Hill/Wong Tai Sin   9905.660377          n            8
#
#    building_age  deal_age  deal_year  \
# 0     55.301848       641       2017
# 1     55.301848       312       2018
# 2     53.215606       511       2017
# 3     19.882272       243       2018
# 4     49.133470       356       2017
#
#                                schoolnet_en               latlon  \
# 0    Kowloon district No. 32 school network  (22.3231, 114.1696)
# 1    Kowloon district No. 32 school network  (22.3231, 114.1696)
# 2  Hong Kong District No. 12 school network  (22.2629, 114.1854)
# 3    Kowloon district No. 43 school network   (22.335, 114.1975)
# 4    Kowloon district No. 41 school network  (22.3298, 114.1911)
#
#   adj_price_per_sqf
# 0       8991.196804
# 1       8261.302969
# 2      30122.817775
# 3      14725.757578
# 4      10919.178555
#
# [5 rows x 21 columns]

# %%
l_mod_col = ['lat','lon', 'adj_price_per_sqf']

#data['lat'] = data.latlon.apply( lambda x: x[0] if type(x) == tuple else np.nan)
#data['lon'] = data.latlon.apply( lambda x: x[1])

size_filter = data.saleablearea <= 1076
df_model = data[size_filter][l_mod_col]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-290-188e42cf6b15> in <module>()
#       1 l_mod_col = ['lat','lon', 'adj_price_per_sqf']
# ----> 2 data['lat'] = data.latlon.apply( lambda x: x[0] if type(x) == tuple else np.nan)
#       3 data['lon'] = data.latlon.apply( lambda x: x[1])
#       4
#       5 size_filter = data.saleablearea <= 1076
#
# ~/.virtualenvs/accelerateHK3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-290-188e42cf6b15> in <lambda>(x)
#       1 l_mod_col = ['lat','lon', 'adj_price_per_sqf']
# ----> 2 data['lat'] = data.latlon.apply( lambda x: x[0] if type(x) == tuple else np.nan)
#       3 data['lon'] = data.latlon.apply( lambda x: x[1])
#       4
#       5 size_filter = data.saleablearea <= 1076
#
# IndexError: tuple index out of range

# %%
data['haslatlon'] = data.latlon.apply( lambda x: True if type(x) == tuple else False)
data.iloc[51538:]
# Out:
#            txdate     price  saleablearea             xaxis             yaxis  \
# 56930  2018-02-14  10000000         848.0          HOUSE 21  SECTION C 6TH ST
# 56931  2017-06-06  11490000         950.0          HOUSE 11  SECTION C 6TH ST
# 56963                   38 BAUHINIA ROAD SOUTH       1987-01-01
# ...                                        ...              ...
# 101841                    77 NGAU TAU KOK ROAD       1981-06-01
# 101842                          1 HARBOUR ROAD       1989-11-01
# 101843                     128 WAN FUNG STREET       1999-01-01
# 101844                     842-850 KING'S ROAD       1960-08-01
# 101845                  111-121 SAI YEE STREET       1962-03-01
# 101846                        232 TONG MI ROAD       1980-11-01
# 101847                       38 KAM LAM STREET       1966-02-01
# 101849                  170-172 HOLLYWOOD ROAD       1965-12-01
# 101850                       9 TONG TAK STREET       2003-01-01
# 101851                        99 TAI TONG ROAD       2001-09-01
# 101852                 138 SHAP PAT HEUNG ROAD       2010-02-01
# 101853                          8 MAN HOP PATH       1976-08-01
# 101857                 3 FUNG YAU STREET SOUTH       1985-05-01
# 101914                 38 TOWN PARK ROAD NORTH       1999-07-01
# 101915                         8 LONG YAT ROAD       1993-10-01
# 101917                      15 NAM NING STREET       1981-12-01
# 101918                    46A BELCHER'S STREET       1978-04-01
# 101921                      18 TAI PO TAU ROAD       1992-03-01
# 101922                          6 PEACE AVENUE       1998-11-01
# 101923                      100 SHING TAI ROAD       1988-03-01
# 101924                   7-19 TSING LUK STREET       1986-11-01
# 101927                    12 WING KWONG STREET       1961-10-01
# 101928                       17 SUNG ON STREET       1991-01-01
# 101929                        18 HOI TING ROAD       2001-12-01
# 101931                         11 HOI FAI ROAD       2000-02-01
# 101932                         1 KIN TUNG ROAD       2005-07-01
# 101933                       6 TAK HONG STREET       1989-12-01
# 101934                       30-38 TAI HO ROAD       1973-04-01
# 101935                       30-38 TAI HO ROAD       1973-04-01
# 101937                        23 YAT MING ROAD       1999-06-01
#
#         numberofunits  numberoffloors  flatsperfloor    ...    price_per_sqf  \
# 56930               1               1              1    ...     11792.452830
# 56931               1               1              1    ...     12094.736842
# 56932               1               1              1    ...      8928.571429
# 56933               1               1              1    ...     11111.111111
# 56934               1               1              1    ...     11666.666667
# 56935               1               1              1    ...     12560.386473
# 56937               1               1              1    ...     10946.859903
# 56938               1               1              1    ...      9478.935698
# 56939               1               1              1    ...     11820.330969
# 56940               1               1              1    ...      9448.028674
# 56941               1               1              1    ...     11130.952381
# 56942               1               1              1    ...     10054.644809
# 56943               1               1              1    ...     10714.285714
# 56944               1               1              1    ...     10345.454545
# 56945               1               1              1    ...     11344.262295
# 56946               1               1              1    ...      7595.238095
# 56947               1               1              1    ...     12094.736842
# 56948               1               1              1    ...     10697.399527
# 56949               1               1              1    ...     14975.845411
# 56951               1               1              1    ...     12690.763052
# 56953               1               1              1    ...     12264.150943
# 56954               1               1              1    ...     11650.943396
# 56956               1               1              1    ...     13333.333333
# 56957               1               1              1    ...      9629.629630
# 56958               1               1              1    ...     12146.226415
# 56959               1               1              1    ...     11690.821256
# 56960               1               1              1    ...     12830.917874
# 56961               1               1              1    ...     12946.859903
# 56962               1               1              1    ...     12946.859903
# 56963               1               1              1    ...      8869.179601
# ...               ...             ...            ...    ...              ...
# 101841            264              33              8    ...     14746.666667
# 101842            622              35             20    ...     25377.643505
# 101843             88              22              4    ...     15714.285714
# 101844             45              11              4    ...     12206.572770
# 101845             96              12              8    ...      9555.984556
# 101846             26              13              2    ...     13590.733591
# 101847            235              13             19    ...      9254.498715
# 101849             12               6              2    ...     12544.529262
# 101850            384              48              8    ...     13798.219585
# 101851            103              13              8    ...     12048.192771
# 101852            144              24              6    ...     11034.482759
# 101853             60               5             12    ...     10553.191489
# 101857            168              21              8    ...     11173.184358
# 101914             76              11              8    ...     10838.445808
# 101915            216              27              8    ...     13476.394850
# 101917            162              26              6    ...     13402.061856
# 101918             81              22              4    ...     13468.013468
# 101921            166              22              8    ...     15492.957746
# 101922             92              23              4    ...     18396.226415
# 101923            144              18              8    ...     14973.262032
# 101924            240              30              8    ...     15247.813411
# 101927              7               7              1    ...      8274.864376
# 101928            104              13              8    ...     15898.058252
# 101929            328              42              8    ...     23232.323232
# 101931            216              37              6    ...     23230.088496
# 101932            419              52              8    ...     11865.008881
# 101933            120              15              8    ...     16400.625978
# 101934            112              19              6    ...     10114.942529
# 101935            112              19              6    ...     11034.482759
# 101937            224              29              8    ...     13460.559796
#
#        flat_type  floor_number building_age  deal_age  deal_year  \
# 56930          d             0    30.882957       278       2018
# 56931          d             0    30.882957       531       2017
# 56932          d             0    41.880903       563       2017
# 56933          d             0    28.881588       430       2017
# 56934          d             0    31.797399       346       2017
# 56935          d             0    25.880903       482       2017
# 56937          d             0    28.881588       591       2017
# 56938          d             0    38.882957       572       2017
# 56939          d             0    41.880903       392       2017
# 56940          d             0    30.882957       607       2017
# 56941          d             0    41.880903       437       2017
# 56942          d             0    25.880903       572       2017
# 56943          d             0    41.880903       341       2017
# 56944          d             0    28.881588       607       2017
# 56945          d             0    41.880903       502       2017
# 56946          d             0    41.880903       607       2017
# 56947          d             0    30.882957       531       2017
# 56948          d             0    41.880903       244       2018
# 56949          d             0    39.882272       546       2017
# 56951          d             0    41.880903       213       2018
# 56953          d             0    36.881588       206       2018
# 56954          d             0    41.880903       311       2018
# 56956          d             0    39.882272       287       2018
# 56957          d             0    38.882957       577       2017
# 56958          d             0    37.880903       196       2018
# 56959          d             0    37.880903       291       2018
# 56960          d             0    34.882957       418       2017
# 56961          d             0    34.882957       515       2017
# 56962          d             0    34.882957       515       2017
# 56963          d             0    31.882272       215       2018
# ...          ...           ...          ...       ...        ...
# 101841         n            10    37.467488         5       2018
# 101842         n            43    29.048597         5       2018
# 101843         n            27    19.882272         5       2018
# 101844         n            12    58.299795         5       2018
# 101845         n             8    56.720055         5       2018
# 101846         n             7    38.047912         5       2018
# 101847         n             9    52.796715         5       2018
# 101849         n             2    52.966461         5       2018
# 101850         n            41    15.882272         5       2018
# 101851         n            16    17.215606         5       2018
# 101852         n             5     8.796715         5       2018
# 101853         n             5    42.299795         5       2018
# 101857         n             9    33.552361         5       2018
# 101914         n             3    19.386721         5       2018
# 101915         n            17    25.133470         5       2018
# 101917         n            26    36.966461         5       2018
# 101918         n            10    40.635181         5       2018
# 101921         n            16    26.718686         5       2018
# 101922         n            10    20.049281         5       2018
# 101923         n            10    30.718686         5       2018
# 56939                               ()      13440.338591      True
# 56940                               ()      11285.197381      True
# 56941                               ()      12514.793031      True
# 56942              (22.4654, 114.1425)      11654.027624      True
# 56943                               ()      11682.319490      True
# 56944                               ()      12357.127669      True
# 56945                               ()      12839.264620      True
# 56946              (22.2544, 113.8621)       9072.131766      True
# 56947                               ()      13649.332207      True
# 56948               (22.225, 114.1121)      11159.766210      True
# 56949              (22.4792, 114.0465)      16989.854618      True
# 56951              (22.4812, 114.0501)      12834.169527      True
# 56953              (22.4834, 114.0458)      12244.508795      True
# 56954                (22.4813, 114.05)      12576.924507      True
# 56956              (22.4777, 114.0473)      14257.660002      True
# 56957                               ()      11231.979124      True
# 56958                               ()      12050.240431      True
# 56959                               ()      12577.912674      True
# 56960              (22.4754, 114.0423)      14453.971419      True
# 56961              (22.4771, 114.0418)      14580.036961      True
# 56962              (22.4771, 114.0418)      14580.036961      True
# 56963              (22.4728, 114.0472)       8969.401926      True
# ...                                ...               ...       ...
# 101841             (22.3253, 114.2157)      14746.666667      True
# 101842             (22.2814, 114.1737)      25377.643505      True
# 101843               (22.346, 114.198)      15714.285714      True
# 101844               (22.29, 114.2091)      12206.572770      True
# 101845             (22.3202, 114.1713)       9555.984556      True
# 101846             (22.3247, 114.1651)      13590.733591      True
# 101847             (22.3169, 114.1672)       9254.498715      True
# 101849             (22.2847, 114.1492)      12544.529262      True
# 101850             (22.3074, 114.2569)      13798.219585      True
# 101851              (22.436, 114.0318)      12048.192771      True
# 101852              (22.439, 114.0198)      11034.482759      True
# 101853             (22.4449, 114.0234)      10553.191489      True
# 101857             (22.4419, 114.0336)      11173.184358      True
# 101914             (22.4415, 114.0171)      10838.445808      True
# 101915              (22.4453, 114.035)      13476.394850      True
# 101917             (22.2493, 114.1537)      13402.061856      True
# 101918             (22.2825, 114.1294)      13468.013468      True
# 101921              (22.454, 114.1622)      15492.957746      True
# 101922             (22.3189, 114.1737)      18396.226415      True
# 101923  (22.278000000000002, 114.2405)      14973.262032      True
# 101924             (22.3539, 114.1049)      15247.813411      True
# 101927   (22.3133, 114.18799999999999)       8274.864376      True
# 101928             (22.3119, 114.1891)      15898.058252      True
# 101929             (22.3154, 114.1635)      23232.323232      True
# 101931              (22.318, 114.1583)      23230.088496      True
# 101932             (22.2919, 113.9488)      11865.008881      True
# 101933             (22.3055, 114.1903)      16400.625978      True
# 101934             (22.3712, 114.1129)      10114.942529      True
# 101935             (22.3712, 114.1129)      11034.482759      True
# 101937             (22.4874, 114.1447)      13460.559796      True
#
# [36760 rows x 22 columns]

# %%
count = -1
for i in data.latlon:
    count += 1
    try:
        lat = i[0]
        lon = i[1]
    except IndexError:
        print(count)
# Out:
# 51538
# 51539
# 51540
# 51541
# 51544
# 51546
# 51547
# 51548
# 51550
# 51551
# 51552
# 51554
# 51561
# 51562
# 51563
# 74945
# 76241
# 76492
# 84427

# %%
clean_dict['21 FAIRVIEW PARK SECTION C, 6TH STREET']
# Out:
# ()

# %%
clean_dict['31 FAIRVIEW PARK SECTION C, 4TH STREET']
# Out:
# (22.4652, 114.1425)
