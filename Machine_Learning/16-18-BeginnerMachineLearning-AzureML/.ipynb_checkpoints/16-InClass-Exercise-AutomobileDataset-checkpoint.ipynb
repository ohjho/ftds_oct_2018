# %% [markdown]
# # Use Python to run the Automobile machine learning exercise done on Azure ML studio
#
# ## Learn Data Science by Doing!
# [Link to Azure ML Studio](https://studio.azureml.net/)
# [Link to Kaggle sklearn regression tutorial](https://www.kaggle.com/andyxie/beginner-scikit-learn-linear-regression-tutorial#)
#
# ### 1. Import Data
# csv here is from ML studio

# %%
import pandas as pd

data = pd.read_csv( 'data/automobile.csv')   # this data set is from Azure ML studio
print(data.dtypes)
data.head(3)
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# ...

# %% [markdown]
# ### 2. Clean Missing Data and Feature Engineering

# %%
l_col_to_use = ['engine-size','horsepower','peak-rpm','city-mpg', 'highway-mpg','price']
df = data.dropna(subset = l_col_to_use).loc[:, l_col_to_use]
df.head(3)
# Out:
#    engine-size  horsepower  peak-rpm  city-mpg  highway-mpg    price
# 0          130       111.0    5000.0        21           27  13495.0
# 1          130       111.0    5000.0        21           27  16500.0
# 2          152       154.0    5000.0        19           26  16500.0

# %% [markdown]
# ### 3. Split Data
# into training and test data
# [another great post](https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6) on test splitting data

# %%
from sklearn.model_selection import train_test_split

l_predictors = l_col_to_use[:-1]
X_train, X_test, y_train, y_test = train_test_split(df.loc[:,l_predictors], df.price, test_size = 0.3, random_state = 0)

print(f'Test data shapes: {X_train.shape} {y_train.shape}')
print(f'Test data shapes: {X_test.shape} {y_test.shape}')
# Out:
# Test data shapes: (139, 5) (139,)
# Test data shapes: (60, 5) (60,)

# %% [markdown]
# ### 4. Train the Model
# A decision tree [tutorial](https://stackabuse.com/decision-trees-in-python-with-scikit-learn/)

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
model = lm.fit(X_train, y_train)

# let's compare it with decision tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
tmodel = regressor.fit(X_train, y_train)

# %% [markdown]
# ### 5. Score the Model

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
prediction = lm.predict(X_test)
score = lm.score(X_test, y_test)

print(f'Linear Regression model Score: {score}')
plt.plot(y_test, prediction, '.')
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Linear Regression model Score: 0.8373574420524548
# Text(0,0.5,'Predictions')

# %%
tprediction = regressor.predict( X_test)
tscore = regressor.score( X_test, y_test)

print(f'Decision Tree Regression model Score: {tscore}')
plt.plot(y_test, tprediction, '.')
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Decision Tree Regression model Score: 0.8843689207442673
# Text(0,0.5,'Predictions')

# %% [markdown]
# ### 6. Deploy the model

# %%
x_input = {'engine-size': [92], 'horsepower': [62],'peak-rpm': [4800],'city-mpg': [27],'highway-mpg': [32]}
x_input = pd.DataFrame.from_dict(x_input)
test = lm.predict(x_input)
test
# Out:
# array([7019.05885645])

# %% [markdown]
# ## Let's try a Classification Experiment
#
# ### 3. Split Data
# now we will predict the make with the six column above

# %%
l_col_to_use = ['engine-size','horsepower','peak-rpm','city-mpg', 'highway-mpg','price', 'make']
df = data.dropna(subset = l_col_to_use[:-1]).loc[:, l_col_to_use]
df.head(3)
# Out:
#    engine-size  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# 0          130       111.0    5000.0        21           27  13495.0
# 1          130       111.0    5000.0        21           27  16500.0
# 2          152       154.0    5000.0        19           26  16500.0
#
#           make
# 0  alfa-romero
# 1  alfa-romero
# 2  alfa-romero

# %%
l_predictors = l_col_to_use[:-1]
X_train, X_test, y_train, y_test = train_test_split(df.loc[:,l_predictors], df.make, test_size = 0.3, random_state = 0)

print(f'Test data shapes: {X_train.shape} {y_train.shape}')
print(f'Test data shapes: {X_test.shape} {y_test.shape}')
# Out:
# Test data shapes: (139, 6) (139,)
# Test data shapes: (60, 6) (60,)

# %% [markdown]
# ### 4. Train the model

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()

cmodel = classifier.fit( X_train, y_train)

# %% [markdown]
# ### 5. Score the model

# %%
cpredict = classifier.predict(X_test)
cscore = classifier.score(X_test, y_test)

pdata = { 'cpredict': cpredict, 'y_test': y_test}
out_df = pd.DataFrame.from_dict(pdata)
out_df['correct'] = out_df.cpredict == out_df.y_test

print(f'Decision Tree Classifier model Score: {cscore}')
print(f'{"{:.2%}".format(sum(out_df.correct)/len(out_df))} correct')
out_df
# Out:
# Decision Tree Classifier model Score: 0.6666666666666666
# 66.67% correct
#           cpredict         y_test  correct
# 19       chevrolet      chevrolet     True
# 175         toyota         toyota     True
# 109         peugot         peugot     True
# 95          nissan         nissan     True
# 182         toyota     volkswagen    False
# 189     volkswagen     volkswagen     True
# 5             audi           audi     True
# 145         subaru         subaru     True
# 13             bmw            bmw     True
# 166       plymouth         toyota    False
# 64           mazda          mazda     True
# 127        porsche        porsche     True
# 170         toyota         toyota     True
# 151         toyota         toyota     True
# 83      mitsubishi     mitsubishi     True
# 7             audi           audi     True
# 34           honda          honda     True
# 135           saab           saab     True
# 38           honda          honda     True
# ...

# %% [markdown]
# ## Further
# * [How to test multiple models](http://ataspinar.com/2017/05/26/classification-with-scikit-learn/)
# * Correct for [multicollinearity](https://towardsdatascience.com/super-simple-machine-learning-by-me-multiple-linear-regression-part-1-447800e8b624)
